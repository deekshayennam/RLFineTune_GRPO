# %% [markdown]
# <a href="https://colab.research.google.com/github/deekshayennam/RLFineTune_GRPO/blob/main/RL_Reasoning_Writing_GRPO_on_base.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h3 align="center"></h3>
# <h1 align="center">RL, Reasoning & Writing</h1>
#
# ---
#
# <h1 align="center">GRPO on Base model</h1>

# %% [markdown]
# This notebook introduces a series of experiment of RL training on a base model, rather than an instruct-model. It is obviously inspired by R0, the *other* DeepSeek model trained from DeepSeekv3: while R1 was more classically post-trained by a series of instruct finetuning and
#
# We reuse the same RL method as R0, GRPO. For a more straightforward way of testing on an instruct model, you can check Will Brown's script that I ported to Google Colab. Here instead we'll take up the opportunity to explore alternative forms of RL tuning that fits better with using a base model as a starting point: poetry writing. We're going to make an RL poet.
#
# <img src="https://raw.githubusercontent.com/Pleias/RL-Reasoning/refs/heads/main/apollinaire_2.png">
#
# It's well known that instruct tuning harms creative writing capabitilies - it has been my frustration ever since ChatGPT got released since I was used to GPT-3 charming, diverse, lustrous style.
#
# We're going to use a new base model pretrained by Pleias, Pleias-350m on an entirely open training set, Common Corpus. Despite its small size (350 million parameters, about the size of GPT-2 medium), Pleias-350m is multilingual and trained on a lot of (public domain) literary works. The model is already able to output poems spontaneously, although in a very "raw" format.
#
# If you're rather used to LLM fine-tuning, the overall code notebook will look quite alien: since we are not even using an instruct version, it is some form of "no-data" training. In the end there is no data aside from the pre-training set. We're just taping into the base model multiverse.

# %% [markdown]
# ## Setting up the models.

# %% [markdown]
# Before getting to the actual matter at hand, let's install the necessary libraries. We'll use vllm to speed up inference training: as a reminder, RL requires generating multiple "drafts" that will then be evaluated using a reward function. The fastest the drafting, the fastest the training and vllm speed up inference considerably in regards to default trl engine.

# %%
# !pip install vllm
# Out:
# Collecting vllm
#   Downloading vllm-0.7.1-cp38-abi3-manylinux1_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from vllm) (5.9.5)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from vllm) (0.2.0)
# Requirement already satisfied: numpy<2.0.0 in /usr/local/lib/python3.11/dist-packages (from vllm) (1.26.4)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from vllm) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from vllm) (4.67.1)
# Collecting blake3 (from vllm)
#   Downloading blake3-1.0.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from vllm) (9.0.0)
# Collecting transformers>=4.48.2 (from vllm)
#   Downloading transformers-4.48.2-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: tokenizers>=0.19.1 in /usr/local/lib/python3.11/dist-packages (from vllm) (0.21.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from vllm) (4.25.6)
# Collecting fastapi!=0.113.*,!=0.114.0,>=0.107.0 (from vllm)
#   Downloading fastapi-0.115.8-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from vllm) (3.11.11)
# Requirement already satisfied: openai>=1.52.0 in /usr/local/lib/python3.11/dist-packages (from vllm) (1.59.9)
# Collecting uvicorn[standard] (from vllm)
#   Downloading uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pydantic>=2.9 in /usr/local/lib/python3.11/dist-packages (from vllm) (2.10.6)
# Requirement already satisfied: prometheus_client>=0.18.0 in /usr/local/lib/python3.11/dist-packages (from vllm) (0.21.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from vllm) (11.1.0)
# Collecting prometheus-fastapi-instrumentator>=7.0.0 (from vllm)
#   Downloading prometheus_fastapi_instrumentator-7.0.2-py3-none-any.whl.metadata (13 kB)
# Collecting tiktoken>=0.6.0 (from vllm)
#   Downloading tiktoken-0.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting lm-format-enforcer<0.11,>=0.10.9 (from vllm)
#   Downloading lm_format_enforcer-0.10.9-py3-none-any.whl.metadata (17 kB)
# Collecting outlines==0.1.11 (from vllm)
#   Downloading outlines-0.1.11-py3-none-any.whl.metadata (17 kB)
# Collecting lark==1.2.2 (from vllm)
#   Downloading lark-1.2.2-py3-none-any.whl.metadata (1.8 kB)
# Collecting xgrammar>=0.1.6 (from vllm)
#   Downloading xgrammar-0.1.11-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (2.0 kB)
# Requirement already satisfied: typing_extensions>=4.10 in /usr/local/lib/python3.11/dist-packages (from vllm) (4.12.2)
# Requirement already satisfied: filelock>=3.16.1 in /usr/local/lib/python3.11/dist-packages (from vllm) (3.17.0)
# Collecting partial-json-parser (from vllm)
#   Downloading partial_json_parser-0.2.1.1.post5-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.11/dist-packages (from vllm) (24.0.1)
# Collecting msgspec (from vllm)
#   Downloading msgspec-0.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.9 kB)
# Collecting gguf==0.10.0 (from vllm)
#   Downloading gguf-0.10.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.11/dist-packages (from vllm) (8.6.1)
# Collecting mistral_common>=1.5.0 (from mistral_common[opencv]>=1.5.0->vllm)
#   Downloading mistral_common-1.5.2-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from vllm) (6.0.2)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from vllm) (0.8.0)
# Collecting compressed-tensors==0.9.0 (from vllm)
#   Downloading compressed_tensors-0.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting depyf==0.18.0 (from vllm)
#   Downloading depyf-0.18.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from vllm) (3.1.1)
# Collecting ray>=2.9 (from ray[default]>=2.9->vllm)
#   Downloading ray-2.41.0-cp311-cp311-manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting nvidia-ml-py>=12.560.30 (from vllm)
#   Downloading nvidia_ml_py-12.570.86-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: torch==2.5.1 in /usr/local/lib/python3.11/dist-packages (from vllm) (2.5.1+cu124)
# Requirement already satisfied: torchaudio==2.5.1 in /usr/local/lib/python3.11/dist-packages (from vllm) (2.5.1+cu124)
# Requirement already satisfied: torchvision==0.20.1 in /usr/local/lib/python3.11/dist-packages (from vllm) (0.20.1+cu124)
# Collecting xformers==0.0.28.post3 (from vllm)
#   Downloading xformers-0.0.28.post3-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (1.0 kB)
# Collecting astor (from depyf==0.18.0->vllm)
#   Downloading astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: dill in /usr/local/lib/python3.11/dist-packages (from depyf==0.18.0->vllm) (0.3.8)
# Collecting interegular (from outlines==0.1.11->vllm)
#   Downloading interegular-0.3.3-py37-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->vllm) (3.1.5)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->vllm) (1.6.0)
# Collecting diskcache (from outlines==0.1.11->vllm)
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: referencing in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->vllm) (0.36.2)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->vllm) (4.23.0)
# Collecting pycountry (from outlines==0.1.11->vllm)
#   Downloading pycountry-24.6.1-py3-none-any.whl.metadata (12 kB)
# Collecting airportsdata (from outlines==0.1.11->vllm)
#   Downloading airportsdata-20241001-py3-none-any.whl.metadata (8.9 kB)
# Collecting outlines_core==0.1.26 (from outlines==0.1.11->vllm)
#   Downloading outlines_core-0.1.26-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm) (3.4.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm) (2024.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch==2.5.1->vllm) (1.3.0)
# Collecting starlette<0.46.0,>=0.40.0 (from fastapi!=0.113.*,!=0.114.0,>=0.107.0->vllm)
#   Downloading starlette-0.45.3-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from lm-format-enforcer<0.11,>=0.10.9->vllm) (24.2)
# Collecting pillow (from vllm)
#   Downloading pillow-10.4.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Collecting tiktoken>=0.6.0 (from vllm)
#   Downloading tiktoken-0.7.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: opencv-python-headless<5.0.0,>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from mistral_common[opencv]>=1.5.0->vllm) (4.11.0.86)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.52.0->vllm) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.52.0->vllm) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.52.0->vllm) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.52.0->vllm) (0.8.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai>=1.52.0->vllm) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9->vllm) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9->vllm) (2.27.2)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.11/dist-packages (from ray>=2.9->ray[default]>=2.9->vllm) (8.1.8)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ray>=2.9->ray[default]>=2.9->vllm) (1.1.0)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.11/dist-packages (from ray>=2.9->ray[default]>=2.9->vllm) (1.3.2)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.11/dist-packages (from ray>=2.9->ray[default]>=2.9->vllm) (1.5.0)
# Collecting aiohttp-cors (from ray[default]>=2.9->vllm)
#   Downloading aiohttp_cors-0.7.0-py3-none-any.whl.metadata (20 kB)
# Collecting colorful (from ray[default]>=2.9->vllm)
#   Downloading colorful-0.5.6-py2.py3-none-any.whl.metadata (16 kB)
# Collecting opencensus (from ray[default]>=2.9->vllm)
#   Downloading opencensus-0.11.4-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: smart-open in /usr/local/lib/python3.11/dist-packages (from ray[default]>=2.9->vllm) (7.1.0)
# Collecting virtualenv!=20.21.1,>=20.0.24 (from ray[default]>=2.9->vllm)
#   Downloading virtualenv-20.29.1-py3-none-any.whl.metadata (4.5 kB)
# Collecting py-spy>=0.2.0 (from ray[default]>=2.9->vllm)
#   Downloading py_spy-0.4.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: grpcio>=1.42.0 in /usr/local/lib/python3.11/dist-packages (from ray[default]>=2.9->vllm) (1.70.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->vllm) (2.4.4)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->vllm) (25.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->vllm) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->vllm) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->vllm) (1.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->vllm) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->vllm) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->vllm) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->vllm) (2024.12.14)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken>=0.6.0->vllm) (2024.11.6)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from tokenizers>=0.19.1->vllm) (0.27.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.48.2->vllm) (0.5.2)
# Collecting pybind11 (from xgrammar>=0.1.6->vllm)
#   Downloading pybind11-2.13.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: pytest in /usr/local/lib/python3.11/dist-packages (from xgrammar>=0.1.6->vllm) (8.3.4)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata->vllm) (3.21.0)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]->vllm) (0.14.0)
# Collecting httptools>=0.6.3 (from uvicorn[standard]->vllm)
#   Downloading httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]->vllm)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]->vllm)
#   Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]->vllm)
#   Downloading watchfiles-1.0.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]->vllm) (14.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai>=1.52.0->vllm) (1.0.7)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema->outlines==0.1.11->vllm) (2024.10.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema->outlines==0.1.11->vllm) (0.22.3)
# Collecting distlib<1,>=0.3.7 (from virtualenv!=20.21.1,>=20.0.24->ray[default]>=2.9->vllm)
#   Downloading distlib-0.3.9-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /usr/local/lib/python3.11/dist-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default]>=2.9->vllm) (4.3.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->outlines==0.1.11->vllm) (3.0.2)
# Collecting opencensus-context>=0.1.3 (from opencensus->ray[default]>=2.9->vllm)
#   Downloading opencensus_context-0.1.3-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: six~=1.16 in /usr/local/lib/python3.11/dist-packages (from opencensus->ray[default]>=2.9->vllm) (1.17.0)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from opencensus->ray[default]>=2.9->vllm) (2.19.2)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.11/dist-packages (from pytest->xgrammar>=0.1.6->vllm) (2.0.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.11/dist-packages (from pytest->xgrammar>=0.1.6->vllm) (1.5.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open->ray[default]>=2.9->vllm) (1.17.2)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=2.9->vllm) (1.66.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=2.9->vllm) (1.26.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=2.9->vllm) (2.27.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=2.9->vllm) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=2.9->vllm) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=2.9->vllm) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=2.9->vllm) (0.6.1)
# Downloading vllm-0.7.1-cp38-abi3-manylinux1_x86_64.whl (264.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.2/264.2 MB 8.6 MB/s eta 0:00:00
# Downloading compressed_tensors-0.9.0-py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 9.4 MB/s eta 0:00:00
# Downloading depyf-0.18.0-py3-none-any.whl (38 kB)
# Downloading gguf-0.10.0-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 7.7 MB/s eta 0:00:00
# Downloading lark-1.2.2-py3-none-any.whl (111 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 kB 12.1 MB/s eta 0:00:00
# Downloading outlines-0.1.11-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.6/87.6 kB 9.3 MB/s eta 0:00:00
# Downloading xformers-0.0.28.post3-cp311-cp311-manylinux_2_28_x86_64.whl (16.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 101.3 MB/s eta 0:00:00
# Downloading outlines_core-0.1.26-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (343 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 343.3/343.3 kB 31.0 MB/s eta 0:00:00
# Downloading fastapi-0.115.8-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 10.1 MB/s eta 0:00:00
# Downloading lm_format_enforcer-0.10.9-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 kB 4.4 MB/s eta 0:00:00
# Downloading mistral_common-1.5.2-py3-none-any.whl (6.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 102.2 MB/s eta 0:00:00
# Downloading nvidia_ml_py-12.570.86-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 4.3 MB/s eta 0:00:00
# Downloading pillow-10.4.0-cp311-cp311-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 105.8 MB/s eta 0:00:00
# Downloading prometheus_fastapi_instrumentator-7.0.2-py3-none-any.whl (18 kB)
# Downloading ray-2.41.0-cp311-cp311-manylinux2014_x86_64.whl (67.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 MB 32.4 MB/s eta 0:00:00
# Downloading tiktoken-0.7.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 60.6 MB/s eta 0:00:00
# Downloading transformers-4.48.2-py3-none-any.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 124.0 MB/s eta 0:00:00
# Downloading xgrammar-0.1.11-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (396 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 396.9/396.9 kB 33.8 MB/s eta 0:00:00
# Downloading blake3-1.0.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (376 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 376.2/376.2 kB 28.7 MB/s eta 0:00:00
# Downloading msgspec-0.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (210 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.7/210.7 kB 22.6 MB/s eta 0:00:00
# Downloading partial_json_parser-0.2.1.1.post5-py3-none-any.whl (10 kB)
# Downloading httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (459 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.8/459.8 kB 35.4 MB/s eta 0:00:00
# Downloading interegular-0.3.3-py37-none-any.whl (23 kB)
# Downloading py_spy-0.4.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 96.4 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading starlette-0.45.3-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 8.7 MB/s eta 0:00:00
# Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 100.3 MB/s eta 0:00:00
# Downloading virtualenv-20.29.1-py3-none-any.whl (4.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 97.1 MB/s eta 0:00:00
# Downloading watchfiles-1.0.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (452 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.6/452.6 kB 42.1 MB/s eta 0:00:00
# Downloading aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Downloading airportsdata-20241001-py3-none-any.whl (912 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 912.7/912.7 kB 66.6 MB/s eta 0:00:00
# Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Downloading colorful-0.5.6-py2.py3-none-any.whl (201 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.4/201.4 kB 23.0 MB/s eta 0:00:00
# Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 5.3 MB/s eta 0:00:00
# Downloading opencensus-0.11.4-py2.py3-none-any.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 15.8 MB/s eta 0:00:00
# Downloading pybind11-2.13.6-py3-none-any.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.3/243.3 kB 26.8 MB/s eta 0:00:00
# Downloading pycountry-24.6.1-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 113.9 MB/s eta 0:00:00
# Downloading uvicorn-0.34.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 6.7 MB/s eta 0:00:00
# Downloading distlib-0.3.9-py2.py3-none-any.whl (468 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 42.3 MB/s eta 0:00:00
# Downloading opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Installing collected packages: py-spy, opencensus-context, nvidia-ml-py, distlib, colorful, blake3, virtualenv, uvloop, uvicorn, python-dotenv, pycountry, pybind11, pillow, partial-json-parser, msgspec, lark, interegular, httptools, gguf, diskcache, astor, airportsdata, watchfiles, tiktoken, starlette, depyf, prometheus-fastapi-instrumentator, lm-format-enforcer, fastapi, aiohttp-cors, xformers, transformers, ray, outlines_core, opencensus, mistral_common, xgrammar, outlines, compressed-tensors, vllm
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.1.0
#     Uninstalling pillow-11.1.0:
#       Successfully uninstalled pillow-11.1.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.47.1
#     Uninstalling transformers-4.47.1:
#       Successfully uninstalled transformers-4.47.1
# Successfully installed aiohttp-cors-0.7.0 airportsdata-20241001 astor-0.8.1 blake3-1.0.4 colorful-0.5.6 compressed-tensors-0.9.0 depyf-0.18.0 diskcache-5.6.3 distlib-0.3.9 fastapi-0.115.8 gguf-0.10.0 httptools-0.6.4 interegular-0.3.3 lark-1.2.2 lm-format-enforcer-0.10.9 mistral_common-1.5.2 msgspec-0.19.0 nvidia-ml-py-12.570.86 opencensus-0.11.4 opencensus-context-0.1.3 outlines-0.1.11 outlines_core-0.1.26 partial-json-parser-0.2.1.1.post5 pillow-10.4.0 prometheus-fastapi-instrumentator-7.0.2 py-spy-0.4.0 pybind11-2.13.6 pycountry-24.6.1 python-dotenv-1.0.1 ray-2.41.0 starlette-0.45.3 tiktoken-0.7.0 transformers-4.48.2 uvicorn-0.34.0 uvloop-0.21.0 virtualenv-20.29.1 vllm-0.7.1 watchfiles-1.0.4 xformers-0.0.28.post3 xgrammar-0.1.11

# %%
# !pip install trl
# !pip install datasets
# Out:
# Collecting trl
#   Downloading trl-0.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: accelerate>=0.34.0 in /usr/local/lib/python3.11/dist-packages (from trl) (1.2.1)
# Collecting datasets>=2.21.0 (from trl)
#   Downloading datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from trl) (13.9.4)
# Requirement already satisfied: transformers>=4.46.0 in /usr/local/lib/python3.11/dist-packages (from trl) (4.47.1)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.34.0->trl) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.34.0->trl) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.34.0->trl) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.34.0->trl) (6.0.2)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.34.0->trl) (2.5.1+cu124)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.34.0->trl) (0.27.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.34.0->trl) (0.5.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets>=2.21.0->trl) (3.17.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.21.0->trl) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets>=2.21.0->trl)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets>=2.21.0->trl) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.21.0->trl) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.21.0->trl) (4.67.1)
# Collecting xxhash (from datasets>=2.21.0->trl)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets>=2.21.0->trl)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets>=2.21.0->trl)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets>=2.21.0->trl) (3.11.11)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.46.0->trl) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.46.0->trl) (0.21.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->trl) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->trl) (2.18.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.21.0->trl) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.21.0->trl) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.21.0->trl) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.21.0->trl) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.21.0->trl) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.21.0->trl) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.21.0->trl) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate>=0.34.0->trl) (4.12.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->trl) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.21.0->trl) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.21.0->trl) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.21.0->trl) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.21.0->trl) (2024.12.14)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate>=0.34.0->trl) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate>=0.34.0->trl) (3.1.5)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.10.0->accelerate>=0.34.0->trl)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.10.0->accelerate>=0.34.0->trl)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.10.0->accelerate>=0.34.0->trl)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.10.0->accelerate>=0.34.0->trl)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.10.0->accelerate>=0.34.0->trl)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.10.0->accelerate>=0.34.0->trl)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.10.0->accelerate>=0.34.0->trl)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.10.0->accelerate>=0.34.0->trl)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.10.0->accelerate>=0.34.0->trl)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate>=0.34.0->trl) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate>=0.34.0->trl) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.10.0->accelerate>=0.34.0->trl)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate>=0.34.0->trl) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10.0->accelerate>=0.34.0->trl) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.10.0->accelerate>=0.34.0->trl) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.21.0->trl) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.21.0->trl) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.21.0->trl) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.21.0->trl) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.10.0->accelerate>=0.34.0->trl) (3.0.2)
# Downloading trl-0.14.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.9/313.9 kB 9.5 MB/s eta 0:00:00
# Downloading datasets-3.2.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 23.9 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 12.5 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 17.8 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 15.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 113.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 88.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 59.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.6 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 10.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 41.3 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 18.7 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 94.3 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 20.7 MB/s eta 0:00:00
# Installing collected packages: xxhash, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, fsspec, dill, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, nvidia-cusolver-cu12, datasets, trl
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.2.0 dill-0.3.8 fsspec-2024.9.0 multiprocess-0.70.16 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 trl-0.14.0 xxhash-3.5.0
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (3.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.17.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.11)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.27.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2024.12.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %% [markdown]
# Now we can start  importing Pleias-350m:

# %%
# First, let's import our required libraries
import torch
from torch.nn import functional as F
from transformers import AutoModelForCausalLM, AutoTokenizer

# Let's use GPT-2 small for this example
model_name = "PleIAs/Pleias-350m-Preview"
model = AutoModelForCausalLM.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %% [markdown]
# Since Pleias-350m is a base model that has never been instruct-tuned, it only we are going to use it in continuation mode like in the good old days of 350m. Given a few lines of poetry, it should predict the next. Let's heat up with some classic:

# %%
# Our input prompt
prompt="""Mine eye hath play'd the painter and hath stell'd
Thy beauty's form in table of my heart;
My body is the frame wherein 'tis held,
And perspective it is best painter's art.
For through the painter must you see his skill,
"""

# %% [markdown]
# We'll start by converting this text into tokens:

# %%
input_ids = tokenizer.encode(prompt, return_tensors='pt')
input_ids = input_ids.to(device)
print(f"\nTokenized input shape: {input_ids.shape}")
print(f"Last Token IDs: {input_ids[0].tolist()[-10:]}")
print(f"Last Decoded tokens: {[tokenizer.decode([id]) for id in input_ids[0].tolist()[-10:]]}")
# Out:
# Tokenized input shape: torch.Size([1, 58])
# Last Token IDs: [1231, 265, 49154, 2103, 699, 2142, 771, 11911, 15, 189]
# Last Decoded tokens: [' through', ' the', ' painter', ' must', ' you', ' see', ' his', ' skill', ',', '\n']

# %% [markdown]
# We'll start doing a full generation first using simply model generate. Let's stick to determinist for now.

# %%
inputs = tokenizer(prompt, return_tensors="pt", padding=False).to(device)

outputs = model.generate(
            inputs.input_ids,
            attention_mask=inputs.attention_mask,
            max_new_tokens=200,
            repetition_penalty=1.2,
            do_sample=False,
            use_cache=True,
            pad_token_id=2,
            eos_token_id=2
        )

result = tokenizer.decode(outputs[0], skip_special_tokens=False)

print(result)
# Out:
# <|end_of_text|>Mine eye hath play'd the painter and hath stell'd
# Thy beauty's form in table of my heart;
# My body is the frame wherein 'tis held,
# And perspective it is best painter's art.
# For through the painter must you see his skill,
# To make a picture perfect ; but to paint
# A face or figure with such perfection as yours,
# Or that which I have seen, would be an act so great
# As if your eyes had been all one size together :
# But this I say, though they are not equal yet,
# I am sure their parts will never fail me till then:
# Their figures shall be like mine, nor can I tell how
# They may become more beautiful than myself.
# THE FAIRY TALE OF THE BABYLONIAN NIGHTS.
# " The fairies' daughters were called by the name of "Babylonians," because they came from Babylonia." — Sir Thomas Browne.
# 1 1. A Fairy Tale.
# By Mr. John Hickes.
# [This story was first published at London in 1609.]
#
# It has long since fallen into disuse among us, being now only known to those who know nothing

# %% [markdown]
# This is very much a typicall "raw" base model output, that reads like an hallucinated book page, with even footnotes, background information, etc. Pleias-350m can also work out in multiple other languages, including 17th century French with historical spelling (something even Claude can struggle with).

# %%
# Our input prompt
prompt="""C’eſt cet amour payé de trop d’ingratitude,
Qui me rend en ces Lieux ſa preſence ſi rude.
Quelle honte pour moy ! Quel triomphe pour luy,
De voir mon infortune égaler ſon ennuy !
"""

inputs = tokenizer(prompt, return_tensors="pt", padding=False).to(device)

outputs = model.generate(
            inputs.input_ids,
            attention_mask=inputs.attention_mask,
            max_new_tokens=200,
            repetition_penalty=1.2,
            do_sample=False,
            use_cache=True,
            pad_token_id=2,
            eos_token_id=2
        )

result = tokenizer.decode(outputs[0], skip_special_tokens=False)

print(result)
# Out:
# <|end_of_text|>C’eſt cet amour payé de trop d’ingratitude,
# Qui me rend en ces Lieux ſa preſence ſi rude.
# Quelle honte pour moy! Quel triomphe pour luy,
# De voir mon infortune égaler ſon ennuy!
# Je ne puis que pleurer, & je n'en veux point dire :
# Mais ce quil y a de plus affreux dans le Monde,
# Ce qui fait ma douleur eſt la perte du monde ;
# Et c'eft à moi-meſine de l'avoir perdu.
# Jamais il n'y eut un homme dont les vertus
# N'eurent jamais tant de gloire auec mes défauts;
# Que jai vu parmy eux tous une vertu fi belle,
# Quelquefois elle ſe perdit avec leur éclat:
# Car ils ont toujours eu des hommes bien faits,
# Pour avoir été heureux quand on étoit malfait.
# Il faut donc que nous ayons quelque chofe de bon,
# Dont nos maux puſſent faire connoitre notre bonté.
# Nous avons beau vouloir, mais nous ne pouvons rien.
# Lui-même eft malheureux comme nous, &c.
# A MONSIEUR

# %% [markdown]
# Now several issues. First you can notice we set up a "repetition penalty", otherwise we get the usual curse of small base models that are getting stuck in repetition loop. Basically the generation possibilities are too open-ended is something that disappear avec instruction tuning. What is nice with Reinforcement Learning: you can correc this bias while still keeping the base model "raw" in continuation mode without any overfitting on instruct set — so given how theses instruction sets have been made, without Chatgptization…

# %% [markdown]
# If we regenerate without the penalty we immediately see the issue:

# %%
outputs = model.generate(
            inputs.input_ids,
            attention_mask=inputs.attention_mask,
            max_new_tokens=200,
            repetition_penalty=1,
            do_sample=False,
            use_cache=True,
            pad_token_id=2,
            eos_token_id=2
        )

result = tokenizer.decode(outputs[0], skip_special_tokens=False)

print(result)
# Out:
# <|end_of_text|>C’eſt cet amour payé de trop d’ingratitude,
# Qui me rend en ces Lieux ſa preſence ſi rude.
# Quelle honte pour moy! Quel triomphe pour luy,
# De voir mon infortune égaler ſon ennuy!
#
#
# Mais ſi je puis, je le puis, & ſi je le veux,
#
#
# Je le puis, & je le veux, & je le veux,
#
#
# Et je le veux, & je le puis, & je le veux,
#
#
# Et je le veux, & je le puis, & je le veux,
#
#
# Et je le veux, & je le puis, & je le veux,
#
#
# Et je le veux, & je le puis, & je le veux,
#
#
# Et je le veux, & je le puis, & je le veux,
#
#
# Et je le veux, & je le puis, & je le veux,
#
#
# Et je le veux, & je le puis, & je le veux,
#
#
# Et je le veux, & je le puis, & je le veux,
#
#
# Et je le veux, & je le puis, & je le veux,

# %% [markdown]
# The other immediate issue: sometimes the model lacks enough context to identify the submission as poetry. But if we really want to make a "poet" it would be even better to switch automatically in poetry mode.

# %% [markdown]
# Let's try with some Keats:

# %%
# Our input prompt
prompt="""Saturn is fallen, am I too to fall?
Am I to leave this haven of my rest"""

inputs = tokenizer(prompt, return_tensors="pt", padding=False).to(device)

outputs = model.generate(
            inputs.input_ids,
            attention_mask=inputs.attention_mask,
            max_new_tokens=200,
            repetition_penalty=1.2,
            do_sample=False,
            use_cache=True,
            pad_token_id=2,
            eos_token_id=2
        )

result = tokenizer.decode(outputs[0], skip_special_tokens=False)

print(result)
# Out:
# <|end_of_text|>Saturn is fallen, am I too to fall?
# Am I to leave this haven of my rest?
# I have no more than a few hours left.
# And if the sun should rise again,
# The moon will be in her place ; and then
# When Saturn shall return from his flight,
# He'll find me here at last! "
#
# " And you are not going away now?" said he, as she
# stood looking down on him with an expression which was
# not very pleasant. She had been thinking that it would
# be better for her husband's health to go back to England;
# but there were many things about which she could not
# understand why they did not come together sooner or
# later. The first thing she thought was how much happi-
# ness might be expected when all these people who lived
# in London met once more — ^how soon their happiness
# would begin to increase! But what was the use of talk-
# ing any longer about such matters? He must see them
# again before long. They seemed so different from

# %% [markdown]
# As you notice immediately we do have some poetry at first and then it switch to novel mode.

# %% [markdown]
# Finally we can notice our poems do not have much structure. Instead we might prefer to have a clear demarcation into verses parts like quatrains or tercets.

# %% [markdown]
# ## Setting up our function rewards

# %% [markdown]
# The good news now: all of theses problems are computable using a simple text algorithmic analysis. No need for LLM as judge or human evaluators, just a proper operationalization of the problem at hand. In an RL context this operationalization is called a "function reward".

# %%
import re
import vllm
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM
from peft import LoraConfig
from datasets import Dataset
from trl import GRPOConfig, GRPOTrainer

# %% [markdown]
# Now let's go back to problem 1: repetition. We are going to generate both a bad and a good query.

# %%
def text_generation(prompt, repetition_penalty=1):
  inputs = tokenizer(prompt, return_tensors="pt", padding=False).to(device)

  outputs = model.generate(
              inputs.input_ids,
              attention_mask=inputs.attention_mask,
              max_new_tokens=200,
              repetition_penalty=repetition_penalty,
              do_sample=False,
              use_cache=True,
              pad_token_id=2,
              eos_token_id=2
          )

  result = tokenizer.decode(outputs[0], skip_special_tokens=False)

  return result

# %% [markdown]
# We'll stick in deterministic mode by enforcing no repetition with the no repetition penalty, but obviously reinforcement learning will be done in non-deterministic mode:

# %%
# Our input prompt
prompt="""C’eſt cet amour payé de trop d’ingratitude,
Qui me rend en ces Lieux ſa preſence ſi rude.
Quelle honte pour moy ! Quel triomphe pour luy,
De voir mon infortune égaler ſon ennuy !
"""

good_generation = text_generation(prompt, repetition_penalty=1.2)
bad_generation = text_generation(prompt, repetition_penalty=1)

# %% [markdown]
# Now let's build a function to check the presence of repetition. I won't comment it in detail, suffice to say it checks both the occurrence of individual words and of n-grams.

# %%
def calculate_repetition_score(text):
    """Calculate a continuous repetition score between 0 and 1.
    Lower scores indicate more repetition, higher scores indicate more uniqueness.
    """
    # Clean and tokenize
    words = text.lower().split()
    if len(words) < 8:  # Very short texts get full score
        return 1.0

    # Calculate various repetition metrics
    from collections import Counter

    # 1. N-gram uniqueness scores (for different n-gram sizes)
    def get_ngram_uniqueness(n):
        ngrams = [' '.join(words[i:i+n]) for i in range(len(words)-n+1)]
        if not ngrams:
            return 1.0
        counts = Counter(ngrams)
        # Calculate ratio of unique n-grams to total n-grams
        uniqueness = len(counts) / len(ngrams)
        # Penalize heavily repeated n-grams
        repetition_penalty = sum(1 for count in counts.values() if count > 2) / len(counts) if counts else 0
        return uniqueness * (1 - repetition_penalty)

    # Get scores for different n-gram sizes
    unigram_score = get_ngram_uniqueness(1)
    bigram_score = get_ngram_uniqueness(2)
    trigram_score = get_ngram_uniqueness(3)
    fourgram_score = get_ngram_uniqueness(4)

    # 2. Local repetition (phrases repeating close to each other)
    def local_repetition_penalty():
        window_size = 10
        local_repetitions = 0
        for i in range(len(words) - window_size):
            window = words[i:i+window_size]
            window_counts = Counter(window)
            local_repetitions += sum(1 for count in window_counts.values() if count > 2)
        return 1 / (1 + local_repetitions)

    local_score = local_repetition_penalty()

    # 3. Vocabulary diversity
    vocab_diversity = len(set(words)) / len(words)

    # Combine scores with weights
    weights = {
        'unigram': 0.1,
        'bigram': 0.2,
        'trigram': 0.3,
        'fourgram': 0.2,
        'local': 0.1,
        'vocab': 0.1
    }

    final_score = (
        weights['unigram'] * unigram_score +
        weights['bigram'] * bigram_score +
        weights['trigram'] * trigram_score +
        weights['fourgram'] * fourgram_score +
        weights['local'] * local_score +
        weights['vocab'] * vocab_diversity
    )

    # Normalize to 0-1 range and make it more sensitive in the middle range
    from math import tanh
    normalized_score = tanh(2 * final_score) / 2 + 0.5

    return normalized_score

# %% [markdown]
# Finally, to make our rating function usable we need to set up a vectorized reward for all completions to come:

# %%
def no_repetition_reward_func(completions, **kwargs) -> list[float]:
    # Handle both string and conversational formats
    responses = []
    for completion in completions:
        if isinstance(completion, str):
            responses.append(completion)
        elif isinstance(completion, list):
            responses.append(completion[0]["content"])
        else:
            raise ValueError(f"Unexpected completion format: {type(completion)}")

    # Calculate continuous scores
    scores = [calculate_repetition_score(response) for response in responses]

    return scores

# %% [markdown]
# Now let's move on to the other issue: enforcing verses even with short prompts.

# %%
prompt="""Saturn is fallen, am I too to fall?
Am I to leave this haven of my rest,
This cradle of my glory, this soft clime,
This calm luxuriance of blissful light"""

good_generation = text_generation(prompt, repetition_penalty=1.2)

prompt="""Saturn is fallen, am I too to fall?
Am I to leave this haven of my rest"""

mixed_generation = text_generation(prompt, repetition_penalty=1.2)

prompt="""Saturn is fallen, am I too to fall?"""

bad_generation = text_generation(prompt, repetition_penalty=1.2)

print("Bad generation")
print(bad_generation)
print("Mixed generation")
print(mixed_generation)
print("Good generation")
print(good_generation)
# Out:
# Bad generation
# <|end_of_text|>Saturn is fallen, am I too to fall?
# And the sun will rise again.
# The moon will be a-rising; and it shall shine as brightly as ever."
# "I have heard of this," said Mr. Hickman, "but not in my own family or mine. It was only when we were young that our father had any idea what he meant by saying so much about his son's going into business. He did say something like this: 'If you are going to make money,' says your father, 'you must do it.' And then there came up from the other side of the house an old woman who sat on one side of him talking with her husband, and she told him all sorts of things which he could never understand at first sight. But after some time they began to talk together more freely than before, till finally their conversation became very animated, and they talked over everything for several hours without speaking another word. Then they went away, leaving me alone with them, and I thought
# Mixed generation
# <|end_of_text|>Saturn is fallen, am I too to fall?
# Am I to leave this haven of my rest?
# I have no more than a few hours left.
# And if the sun should rise again,
# The moon will be in her place ; and then
# When Saturn shall return from his flight,
# He'll find me here at last! "
#
# " And you are not going away now?" said he, as she
# stood looking down on him with an expression which was
# not very pleasant. She had been thinking that it would
# be better for her husband's health to go back to England;
# but there were many things about which she could not
# understand why they did not come together sooner or
# later. The first thing she thought was how much happi-
# ness might be expected when all these people who lived
# in London met once more — ^how soon their happiness
# would begin to increase! But what was the use of talk-
# ing any longer about such matters? He must see them
# again before long. They seemed so different from
# Good generation
# <|end_of_text|>Saturn is fallen, am I too to fall?
# Am I to leave this haven of my rest,
# This cradle of my glory, this soft clime,
# This calm luxuriance of blissful light?
# I have been here for a long time.
# And now the sun has set; and all around
# Is dark as night: but still there are stars!
# The moon's pale beams glimmer on these shores ;
# They shine upon me like the morning star :
# But they do not reach their full extent!
# There lies an ocean wide, with billows bound,
# That seem to be no more than waves that roll
# Into one great deep — ^the sea itself.
# SATURN IS FALLEN. 1^5
#
# It was in vain that Saturn sought his home,
# His native land, his country, or his throne.
# He had lost it by some unseen hand.
# For he could never find another place.
# Nor any other way out from its abyss.
# To seek him where he might dwell alone.
# No longer did he wish to live among men.
# Or even to see them happy once again.

# %% [markdown]
# Let's target first the bad generation (the one that switch nearly immediately to prose mode due to bad poetry inertia)

# %%
from statistics import mean

prompt = "Saturn is fallen, am I too to fall?"

#First we get the values from the initial prompt:
prompt_lines = [line.strip() for line in prompt.split('\n') if line.strip()]
prompt_lengths = [len(line) for line in prompt_lines]
target_length = mean(prompt_lengths)

lines = [line.strip() for line in bad_generation.split('\n') if line.strip()]

#Then we analyze the generations.
line_lengths = [len(line) for line in lines]
actual_mean = mean(line_lengths)
length_ratio = actual_mean / target_length
print(length_ratio)

uppercase_count = sum(1 for line in lines if line and line[0].isupper())
uppercase_ratio = uppercase_count / len(lines)

print(uppercase_ratio)

# Text is verse-like if:
# 1. Mean line length is within 30% of prompt
# 2. At least 80% of lines start with uppercase
is_verse_like = (0.7 <= length_ratio <= 1.3) and (uppercase_ratio >= 0.8)

print(is_verse_like)
# Out:
# 6.642857142857143
# 0.5
# False

# %% [markdown]
# So definitely a bad generation: lines are on average 6 times longer as the original prompt and only half of them start with an upper case.

# %% [markdown]
# At this point let's consolidate into a function:

# %%
from statistics import mean

def check_verse(prompt, completion):

  #First we get the values from the initial prompt:
  prompt_lines = [line.strip() for line in prompt.split('\n') if line.strip()]
  prompt_lengths = [len(line) for line in prompt_lines]
  target_length = mean(prompt_lengths)

  lines = [line.strip() for line in completion.split('\n') if line.strip()]

  #Then we analyze the generations.
  line_lengths = [len(line) for line in lines]
  actual_mean = mean(line_lengths)
  length_ratio = actual_mean / target_length

  print("Length ratio:")
  print(length_ratio)

  uppercase_count = sum(1 for line in lines if line and line[0].isupper())
  uppercase_ratio = uppercase_count / len(lines)

  print("Uppercase ratio:")
  print(uppercase_ratio)

  # Text is verse-like if:
  # 1. Mean line length is within 30% of prompt
  # 2. At least 80% of lines start with uppercase
  is_verse_like = (0.7 <= length_ratio <= 1.3) and (uppercase_ratio >= 0.8)

  return is_verse_like

# %%
print("Mixed generation")
print(check_verse(prompt, mixed_generation))

print("\nGoog generation")
print(check_verse(prompt, good_generation))
# Out:
# Mixed generation
# Length ratio:
# 1.3473684210526315
# Uppercase ratio:
# 0.3157894736842105
# False
#
# Goog generation
# Length ratio:
# 1.1324675324675324
# Uppercase ratio:
# 0.9545454545454546
# True

# %% [markdown]
# So clearly function is working: the mixed generation nearly pass the length lines requirement (as the prose part is outputted line by line), but not the uppercase requirement. Good generation is all fine.

# %% [markdown]
# Similarly as previous, let's wrap it up into a function. This time, we include both the prompts and the completions:

# %%
from statistics import mean

def check_verse(prompt, completion):

  try:
    #First we get the values from the initial prompt:
    prompt_lines = [line.strip() for line in prompt.split('\n') if line.strip()]
    prompt_lengths = [len(line) for line in prompt_lines]
    target_length = mean(prompt_lengths)

    lines = [line.strip() for line in completion.split('\n') if line.strip()]

    #Then we analyze the generations.
    line_lengths = [len(line) for line in lines]
    actual_mean = mean(line_lengths)
    length_ratio = actual_mean / target_length

    uppercase_count = sum(1 for line in lines if line and line[0].isupper())
    uppercase_ratio = uppercase_count / len(lines)

    # Text is verse-like if:
    # 1. Mean line length is within 30% of prompt
    # 2. At least 80% of lines start with uppercase
    is_verse_like = (0.7 <= length_ratio <= 1.3) and (uppercase_ratio >= 0.8)

  except:
    is_verse_like=False

  return is_verse_like

def verse_reward_func(prompts, completions, **kwargs) -> list[float]:
    return [0.5 if check_verse(prompt, response) else 0.0 for prompt, response in zip(prompts, completions)]

# %% [markdown]
# Finally let's try to add some built-in structure. We won't aim for anything complex yet: just favoring poems formatted with blocks of four verses, the quatrain.
#
# Since it willl be the most dramatic function we also include a print function: we'll be able to check in the way the learning progression of our RL model.

# %%
def check_quatrain(text):
    # Split text by double newlines to get stanzas
    raw_groups = text.split('\n\n')

    # Process each group to get non-empty lines
    verse_groups = []
    for group in raw_groups:
        lines = [line.strip() for line in group.split('\n') if line.strip()]
        if lines:  # Only add non-empty groups
            verse_groups.append(lines)

    if not verse_groups:
        return 0.0

    # Count groups of exactly 4 verses
    quatrain_count = sum(1 for group in verse_groups if len(group) == 4)

    print("Poem:")
    print(text)
    print("Quatrain estimation: " + str(quatrain_count))

    # Return reward equal to the number of quatrains found
    # If no quatrains are found, return 0
    return float(quatrain_count) if quatrain_count > 0 else 0.0

def quatrain_reward_func(prompts, completions, **kwargs) -> list[float]:
    return [check_quatrain(completion) for completion in completions]

# %% [markdown]
# Now let's check the quatrain detection method on a sonnet from Petrarch:

# %%
sonnet = """Ace non trovo, e non ho da far guerra;
E temo, e spero, ed ardo, e son’ un ghiaccio;
E volo sopra ’l cielo, e giaccio in terra;
E nulla stringo, e tutto ’l mondo abbraccio.

Tal m’ha in prigion, che non m’apre, nè serra,
Nè per suo mi riten, nè scioglie il laccio;
E non m’ancide Amor’, e non mi sferra,
Nè mi vuol vivo, nè mi trae d’impaccio.

Veggio senz'occhi; e non ho lingua, e grido;
E bramo di perir, e cheggio aita;
Ed ho in odio me stesso, ed amo altrui:

Pascomi di dolor; piangendo rido;
Egualmente mi spiace morte, e vita.
In questo stato son, Donna, per vui. """

check_quatrain(sonnet)
# Out:
# 2.0

# %% [markdown]
# Two quatrain, it's all good: we are ready to go.

# %% [markdown]
# ## Setting up the RL dataset

# %% [markdown]
# At this point we have the first part of the RL pipeline: two reward function that determines whether the generation was a success or not. All we need now is just a collection of seed prompt and, oh wait, where is there any good LLM dataset for poetry?

# %% [markdown]
# There are almost no one but, as it happens, I'm just in the middle of a big data parsing of Wikisource and this is as good as an occasion as any to introduce the largest set of public domain "verses": 207,554 individual verses randomized. Likely enough for some nice training.

# %%
import pandas as pd
dataset = pd.read_parquet("https://huggingface.co/datasets/PleIAs/verse-wikisource/resolve/main/verse_wikisource.parquet")

# %%
dataset
# Out:
#                                                     verse  size_verse  \
# 0              Pensive to foster cares, careless of joys;           7
# 1                    On the obscure and fluctuating main,           6
# 2       On the floor the poor mother groped madly abou...          15
# 3               To tower up in completeness, trophy-like,           6
# 4        The waves cleave not to him nor he to the waves;          11
# ...                                                   ...         ...
# 207549             And meets me with ten thousand smiles!           7
# 207550  And all the souls that her burden madeCried ou...          12
# 207551  Other times, stung by the œstrum of some swift...          10
# 207552              They smelled a dead one passing near!           7
# 207553                   As, with a backward wave to her,           7
#
#         order_verse                                              title  \
# 0               742                              St. Peter's Complaint
# 1                 8  Elegiac Sonnets, and Other Poems, Volume 2, Th...
# 2                81                                    The Last Bullet
# 3               357                           Balaustion's Adventure/V
# 4                24                                       Ode to Youth
# ...             ...                                                ...
# 207549           22                              Blockhead and Beehive
# 207550          185               The Story and Song of Black Roderick
# 207551           11                   The Bothie of Toper-na-fuosich/3
# 207552           94   The Czechoslovak Review/Volume 3/Spectre's Bride
# 207553           22  An Anthology of Australian Verse/The Sliprails...
#
#                                                      link
# 0       https://en.wikisource.org/wiki/St%2E%5FPeter%2...
# 1       https://en.wikisource.org/wiki/Elegiac%5FSonne...
# 2       https://en.wikisource.org/wiki/The%5FLast%5FBu...
# 3       https://en.wikisource.org/wiki/Balaustion%27s%...
# 4         https://en.wikisource.org/wiki/Ode%5Fto%5FYouth
# ...                                                   ...
# 207549  https://en.wikisource.org/wiki/Blockhead%5Fand...
# 207550  https://en.wikisource.org/wiki/The%5FStory%5Fa...
# 207551  https://en.wikisource.org/wiki/The%5FBothie%5F...
# 207552  https://en.wikisource.org/wiki/The%5FCzechoslo...
# 207553  https://en.wikisource.org/wiki/An%5FAnthology%...
#
# [207554 rows x 5 columns]

# %% [markdown]
# We are going to make some slight changes to get into prompt mode, including prepending a newline so that our RL pipeline gets at least a "clue" that we are expecting some poetry.

# %%
prompt_list = []

for verse in dataset["verse"].tolist()[0:1000]:
  prompt_list.append(f"{verse}\n")

dataset = Dataset.from_dict({'prompt': prompt_list})

dataset
# Out:
# Dataset({
#     features: ['prompt'],
#     num_rows: 1000
# })

# %%
dataset[0]
# Out:
# {'prompt': 'Pensive to foster cares, careless of joys;\n'}

# %% [markdown]
# ## Training

# %% [markdown]
# We have now everything to do some actual training.

# %% [markdown]
# Let's define some directory (not featured here, but if you want to keep persistent traces, you might want to connect your colab to the Drive).

# %%
output_dir="outputs/Pleias-350m-GRPO"
run_name="Pleias-350m-GRPO-Poetry"

# %% [markdown]
# Since it's a small model and there are anyway some instabilities issues, we're dropping Peft. Most of the arguments are rather standard (if you've done any fine tuning, you're in familiar territory). In contrast with the llama GRPO script I'm lowering the completion length as poems do not need to be that long anyway.

# %%
training_args = GRPOConfig(
    output_dir=output_dir,
    run_name=run_name,
    learning_rate=5e-5,
    adam_beta1 = 0.9,
    adam_beta2 = 0.99,
    weight_decay = 0.1,
    warmup_ratio = 0.1,
    lr_scheduler_type='cosine',
    logging_steps=1,
    bf16=True,
    per_device_train_batch_size=1,
    gradient_accumulation_steps=4,
    num_generations=16,
    max_prompt_length=256,
    max_completion_length=200,
    num_train_epochs=1,
    save_steps=100,
    max_grad_norm=0.1,
    log_on_each_node=False,
    use_vllm=True,
    vllm_gpu_memory_utilization=.3,
    vllm_device="cuda:0",
    report_to="none" #I'm disabling Wandb.
)
# Out:
# torch.distributed process group is initialized, but parallel_mode != ParallelMode.DISTRIBUTED. In order to use Torch DDP, launch your script with `python -m torch.distributed.launch

# %% [markdown]
# Unfortunately due to a persistent bug either on GRPO or tokenizer config side, we have to wrap the tokenizer (sorry for verbose code)

# %%
# First, initialize your tokenizer as before
tokenizer = AutoTokenizer.from_pretrained(model_name,
    padding_side="left"
)
tokenizer.eos_token = "<|end_of_text|>"
tokenizer.pad_token = tokenizer.eos_token
tokenizer.pad_token_id = tokenizer.eos_token_id
tokenizer.padding_side = "left"

class TokenizerWrapper:
    def __init__(self, base_tokenizer):
        self.base_tokenizer = base_tokenizer

        # Explicitly set important attributes
        self.pad_token_id = base_tokenizer.pad_token_id
        self.eos_token_id = base_tokenizer.eos_token_id
        self.padding_side = base_tokenizer.padding_side
        self.vocab_size = base_tokenizer.vocab_size
        self.pad_token = base_tokenizer.pad_token
        self.eos_token = base_tokenizer.eos_token

        # Copy remaining attributes
        for attr_name in dir(base_tokenizer):
            if not attr_name.startswith('_') and not hasattr(self, attr_name):
                setattr(self, attr_name, getattr(base_tokenizer, attr_name))

    def __call__(self, *args, **kwargs):
        kwargs['return_token_type_ids'] = False
        outputs = self.base_tokenizer(*args, **kwargs)
        if isinstance(outputs, dict) and 'token_type_ids' in outputs:
            del outputs['token_type_ids']
        return outputs

    def batch_decode(self, *args, **kwargs):
        return self.base_tokenizer.batch_decode(*args, **kwargs)

    def decode(self, *args, **kwargs):
        return self.base_tokenizer.decode(*args, **kwargs)

# Wrap your tokenizer
wrapped_tokenizer = TokenizerWrapper(tokenizer)

# Create your trainer with the wrapped tokenizer
trainer = GRPOTrainer(
    model=model,
    processing_class=wrapped_tokenizer,
    reward_funcs=[
        no_repetition_reward_func,
        verse_reward_func,
        quatrain_reward_func
    ],
    args=training_args,
    train_dataset=dataset
)
# Out:
# /usr/local/lib/python3.11/dist-packages/trl/trainer/grpo_trainer.py:301: UserWarning: The requested device cuda:0 is also used for training. This may lead to unexpected behavior. It is recommended to use a dedicated device for vLLM.
#   warnings.warn(
# INFO 02-02 19:43:56 config.py:526] This model supports multiple tasks: {'generate', 'score', 'embed', 'reward', 'classify'}. Defaulting to 'generate'.
# INFO 02-02 19:43:56 llm_engine.py:232] Initializing a V0 LLM engine (v0.7.1) with config: model='PleIAs/Pleias-350m-Preview', speculative_config=None, tokenizer='PleIAs/Pleias-350m-Preview', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=2048, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda:0, decoding_config=DecodingConfig(guided_decoding_backend='xgrammar'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=0, served_model_name=PleIAs/Pleias-350m-Preview, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=False, chunked_prefill_enabled=False, use_async_output_proc=True, disable_mm_preprocessor_cache=False, mm_processor_kwargs=None, pooler_config=None, compilation_config={"splitting_ops":[],"compile_sizes":[],"cudagraph_capture_sizes":[256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"max_capture_size":256}, use_cached_outputs=False,
# INFO 02-02 19:44:02 model_runner.py:1111] Starting to load model PleIAs/Pleias-350m-Preview...
# INFO 02-02 19:44:02 weight_utils.py:251] Using model weights format ['*.safetensors']
# INFO 02-02 19:44:02 weight_utils.py:296] No model.safetensors.index.json found in remote.
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# INFO 02-02 19:44:08 model_runner.py:1116] Loading model weights took 0.6828 GB
# INFO 02-02 19:44:19 worker.py:266] Memory profiling takes 5.65 seconds
# INFO 02-02 19:44:19 worker.py:266] the current vLLM instance can use total_gpu_memory (39.56GiB) x gpu_memory_utilization (0.30) = 11.87GiB
# INFO 02-02 19:44:19 worker.py:266] model weights take 0.68GiB; non_torch_memory takes 0.00GiB; PyTorch activation peak memory takes 0.60GiB; the rest of the memory reserved for KV Cache is 10.59GiB.
# INFO 02-02 19:44:25 executor_base.py:108] # CUDA blocks: 13342, # CPU blocks: 5041
# INFO 02-02 19:44:25 executor_base.py:113] Maximum concurrency for 2048 tokens per request: 104.23x
# INFO 02-02 19:44:28 model_runner.py:1435] Capturing cudagraphs for decoding. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI. If out-of-memory error occurs during cudagraph capture, consider decreasing `gpu_memory_utilization` or switching to eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# Capturing CUDA graph shapes: 100%|██████████| 35/35 [06:36<00:00, 11.32s/it]
# INFO 02-02 19:51:05 model_runner.py:1563] Graph capturing finished in 396 secs, took 0.14 GiB
# INFO 02-02 19:51:05 llm_engine.py:429] init engine (profile, create kv cache, warmup model) took 416.48 seconds

# %%
trainer.train()
# Out:
# Poem:
#
# Pattison — Boodle's to bis pleasure — Charles II.'s "Adonais."
#
# Some hear what ye do. You young lady,
#
# In love's most hummer martyrdom!
#
# Bright eyes are glowing o'er your fair face.
# Steadfast brow, and steady eye.
# Digitized by VjOOQIC
#
#
#
# 228 SEVENTEENTH CENTURY.
# The same glance on moonhght, and the same
#
# Written words of passionate cry.
# Never can it be forgot,
#
# That now you teil me. When you will.
# Or sound me a short threat.
# Hammer-bird, in vain you seek to kill.
# And not to pinch you at last.
# Awake, awakon, my spirit.
# And rouse me slowly from yon gew-day 1
# CALL me, my darling — call me T
#
#
#
# Sad is the
# Quatrain estimation: 0
# Poem:
#
# Until they have pardon'd our sin and made
#
# That sight, which proves such pain, a sight of wrath, 43
#
# Which is to punishment all an assail.
# Thus the painter, so that he may not rash
#
# Such art-work, the painting must not depart;
#
# Or the more pure, the more unpity'd saint
#
# Never saw mortals naked, sick, or lame,
#
# Spider-stricken, or any man but man.
# The touch, the breath and the contact are all
#
#
#
# M
#
#
#
# The Platonic Drama.
# 187
#
#
#
# All, except the touch, the carbonic acid, and the
# carbonic oxide. The principle of inquiry,
# then, in the five triatomics, is essentially
# the same as in the five lofty theories of poetic
# poetry. The greatest effect is produced by those
# principles which the philosopher is
# Quatrain estimation: 0
# Poem:
# Who, virtuous Amphion, the beaconed wastes,
# Can charm the helpless, the slipping barren ;
# Smooth as the seam along the wave, or lair
# Of the white gull, or low in Bithynia's air,
# Or in the rosy brook of the limpid sea.
# No pity now, but light to the old one's face,
# Stamp'd with a shudder and a dry pain, —
# " No pity! " I cried, " for the last, I pray.
# Spare this sorrow, Drive the eagle from the
#
# northern sky!
#
# Will this new sun and moon let thine :
#
# Theer, Hebe, o'er the tide broad ocean flows ;
#
# Will it, the eagle's winged echoes sweep,
#
# Flush the purple sea with azure-bright light,
#
# And the sun's point
# Quatrain estimation: 0
# Poem:
# The Sphinx, but in vain she taunts us with her guise,
#
# Thus say they, differently from us —
#
# The gods have learnt — we are painfully amazed.
# Of which lamenting each one fancied it was
# To be in Spain the consummate and distressed.
# But I--why there's no doubi--the most remote
# Of all her lovers — hopeless of any kind,
# When the best and most inviting can be found.
# That is only a god ; for she returns to me.
# And I then too, by her side in his armour.
# Offset whence the Cyclops with magicians Loves
#
# Who some great rage against him had constantly
# To his Roman beauteous loss performed,
#
# Unharmed, unscathed, or with their quarrel won.
# Heaven, who all these hearts thrusts into one andthe,
# Like remorseless
# Quatrain estimation: 0
# Poem:
# (Could you, or are you thine?) They laugh wherever-
# you in polka,
# Leave them in polka.
# See
#
# COMIC until I die.
# 3. SECOND HOUR.
# A Boy.
# I mud see a mouse, and bring some honey.
# I guess he can't be poisonous to you, for he's
# a very nice animal, though, you see, he's damn
# good, so deserves wearing glasses and having
# a shawl.
# I guess he won't be. Ah, Gordius to kill by
# poison!
#
# 4. A Singer.
# If you ever bring poison into your throat
# with your tongue-itch, or a mouser's mouth-
# ache, tell me any stale one, I hope you won't
# be guilty of it.
# Fools
#
#
#
# Fools, why not you?
# Fools, we call you wittii^s
# Quatrain estimation: 1
# Poem:
# They bless us for our pains, and give us Laughter,
# Beulah!
#
#
#
# TRIBUTED TO MRS. THEODORE DRAYTON BARDE.
# Quatrain estimation: 0
# Poem:
# Nor mercy but alone on His name
# Is ours. Siegfried was some god, but in our
# Time
# Conquered Hercules, Alcestis, the gate
# Of heaven, sought him too ungratefully,
# To superhuman gain. Now, the mighty
# History of our time hath this great theme impressed
# Upon us: heavenly incense and a-horse, too
# Assoiffient to restrain our tears:
# Oppressed it, indeed, scarred it, and now
# It is quite spared. The incense well we'll
# Revive
# At the great door of Heaven, entering by a
# Great cathedral or tomb, from the forehead,
# It sleeps sweet. And in the sacred pile,
# Among its classical books, there dwell the
# Painting of the Night That was both eternal And ever changed ;
# The summits lofty in the hoisting
# Wings of a Column, as might
# Quatrain estimation: 0
# Poem:
#
# And not a spark of vengeance will you save,
# And Phosphor Diogenes, (our last star,)
#
# That yet once has not yet left his fate.
# Each of your brandiess broken, " Look up, ye Gods,"
#
#
#
# Digitized by
#
#
#
# Google
#
#
#
# THE PENITENT. 473
#
# " But ah, what think you will become of me?"
#
# Are they at strife between us these to say?
#
# And the world spurns op meats, if you will
#
# Take his cakes too and his omers in both hands.
# Let £Ester die thus ; life is too short ;
#
# My cap, my mouth, you must not claim this length.
# For nothing will I do till we shall know
#
# Were z eaves at length sunk by z fire that burned.
# Your scornful Saturn silently overflows
#
# (Unarm the Gods.)
# Quatrain estimation: 0
# Poem:
#
# Molten with pain. The ghost of one who slew
#
# The hero of the day, and died scarcely long
#
# Since, only to be shunned, for God and Man
#
# He lives and mourns, —
#
# Whom, perhaps, even now the Spirits of the
#
# Tomb pass through my eyes ; and who from my
#
# Soul has drawn a loving, fond, fond embrace
#
# On one who came to find the Death of me!
#
# And thou, the dead Mother of Juno, whose
#
# .Eyes on me smiled, when I to thee was
#
# Forgiven, my sinner, and still more forsaken,
#
# Do weep, O weep ; who know not that my
#
# Foe, who came to me, — stolen from my soul,
#
# And white as Ind, — would some day awake ;
#
# Whose memory so long has been with
# Quatrain estimation: 0
# Poem:
# The Gods, the Thyreias, and the Muses,
# Because we are bond-servants, and poverty
# Is the hindrance of our poverty.
#
#
# Identify the different entities mentioned in the text and describe their relationships with each other, especially focusing on how they are connected to each other.
#
# {
#     "type":"object",
#     "properties":{
#         "entities":{
#             "type":"array",
#             "items":{
#                 "type":"object",
#                 "properties":{
#                     "name":{
#                         "type":"string"
#                     },
#                     "relationships":{
#                         "type":"array",
#                         "items":{
#                             "type":"object",
#                             "properties":{
#                                 "with":{
#                                     "type":"string"
#                                 },
#                                 "description":{
#                                     "type":"string"
#                                 }
#                             },
#                             "required":[
#                                 "description",
#                                 "with"
#
# Quatrain estimation: 0
# Poem:
# Those mean, unscrupulous lying crew.
# They magnify the Dynasts and Princes,
# Their falsebohemian virtues are a scare;
# Their giants, tyrants, and fierce whores are all.
# And ferocity, that nothing could repel,
# Tries to annoy me till it tells me,
# That your fair women are a laughing-stock
# Which other men must own their charms as old.
# Who saw your women play their darling game
# In the old courts of Pisa and Rome.
# Have they not secret ways to find
# The'monasteries of women too,
# And mix religiously their lives,
# As they suffize for those retinue?
# And only marry then to be seen?
# Had I ever done, as now I do,
# A wrong to women, and to be known?
# Can books be men, if friends descended,
# And guiltless passions cons
# Quatrain estimation: 0
# Poem:
#
# Their impious riot, their basest sacrilege;
#
# Free, they say, but with such hearts, but with such eyes,
#
# As their own, they should feast to the public eye,
#
# The world's despair, and the name of its destroyer.
# Oft will I hear whate'er they never said,
#
# Persecuted for that they cannot pardon.
# And feel my fate, my weak consorted will,
#
# And chide my reason's evil spirits, hear the will
#
# Of that contemptible heart, whose mission is cruel,
#
# Who from the grape-vine faints its happy sun,
#
# Hung by a self-devoted porcupine.
# OwdYe whit the yeoman's feat, my dear friend,
#
# A madish dog that eats' the jugglers brain;
#
# He loves to be deculted, gnaw'd,
# Quatrain estimation: 0
# Poem:
#                     far more than Vergil forgives the fault of a child, not to be forgotten
#                      for as young a child as ever was born in the world. For whom,
#                      then, would Homer pity us, if not the Gods? And woe is me:
#                      I, beautiful as the sun, have been deprived of all tenderness and of all
#                      joy. Can such prayer be more than the natural remains of
#                      the solidarity of living and living beings? and the Gods, who have
#                      so long sighed, were to offer their forgiveness who, when no complaints
#                      had been heard, had offended them by their insatiate self-indulgence.
#                      But, surely, the Gods are not such as you imagine, Divy, and have not
#                      concealed themselves from me to make me sorry for your injuries; hence,
#                      too, we have not enough compassion for those who have tortured thee as a
#
# Quatrain estimation: 0
# Poem:
# We, too, to their great pity to own.
# While he, recalling the long and long series
# Of times, when Apollo, the Heaven-god,
# In dark Olympus, thus wrought like a man
# A sculpture, that soars with lightning on the skies,
# The inspired and mortal self-same god,
# There is no venturing now, though sin and crime
# Have with countless voices screamed amidst,
# Of late, to his due space, to make him play.
#
#
# Identify and structure the relationships between different entities mentioned in the text, such as individuals, gods, supernatural beings, and the universe.
#
# {"type":"object",
# "properties":{"relationships":{"type":"object",
# "properties":{"individuals":{"type":"array"},"gods":{"type":"array"},"supernatural_beings":{"type":"array"},"universe":{"type":"array","items":{"type":"string"}}},"required":["divine_power","gods","
# Quatrain estimation: 0
# Poem:
# Nay, nobly, but not do is the truth, the virtue of I
# They walk before us in these little shadowy forms,
# Seeing us standing and seeing that not that we
# Can reconcile ourselves to it — by our easy skill.
# They taste it — we see on it an unquestioning pleasure.
# And just as our Nature, strong in the need,
# Deeds of our sufferance manifest, we see ;
# From morning to noon that good, that good which befalls
# Theorising, as the poet pictures 'tis, to-day,
# The same relationship we still've to the world
# Boding the long-suffering of the past, as of old.
# The Gods, who see what is, and their lessening smile
# Turn seized on us and gripe our lips; and the same,
# Having looked at me, and seeing our actions
# Still weakened by our ignorance of success,
#
# Quatrain estimation: 0
# Poem:
#
# They thus forget; yet,
#
# Would I were free,
#
# To live so many years! not only so!
#
#
#
#
#
# No, how can I, if ever yet
# Still in distressand in pain
# Struggled, and thus besmirched my mind?
# How could I bring home to my own mind
# What years command, and as I go on,
# I look back to that past, and see
# The shades of unfinished things set
# On the road to the forgotten place.
# Ah! all […] I am hardly conscious
# Of the dear dear, by his side, kept in wait
# For him to meet, and also so kept away
# From his long close scrutiny till the end
# Of time. And then I am conscious
# Of how unkindly he looks at me, —
# So does the Count.
# He was a most observant eye.
# He watched when I walked here and there,
# Quatrain estimation: 0
# Poem:
#     And hung ere yet the soft sleep of the morrow. In the white spring that dies I may see him more,
#     In the light image of the old world now wreathed in wreaths,
#     And for her reality I should rejoice;
#     I should say of her,--for it is my grief,--
#     "O my husband, my dear husband!"
#
# AH, but those dim canopy shadows in which
#     Forever to know shall I wear his name;
#     The silent roses that meet him in life
#     Where the fairest tale shall never have been told;
#     The speck of twilight in the frosty night,
#     That is to light as the light of the sun;
#     The dyeing of his crown, like the sands on the sea
#     In the darkening blast,--it must thither come,
#     To break the heart of the brave man of Lee;
# Quatrain estimation: 0
# Poem:
# And, through a cloud shroud'd the olive-voices.
# Neath deep and purple moisture, at the call
# Of olives and figs you conquered him.
# If breathed above you among the hills
# A song more glorious than that of Cynthia's
# From its dew-white gravel mountain to the
# Ventilator of the heaven, Lady Monthdike
# With an angel maiden you drove in a chariot
# Of light and verdure, and from the desert
# You came to meet the heart of lovers, with
# Charms fair and loves rare, which every dream
# Of empty hour lift up their hearts in
# vourts.
# If all the good you heard and all the good
# said
# Was but the stamp of silence and a dread.
# So your voice and your words pierced the dark-faced
# syce
# Of lovers with delight and joy,
# And all that you said, with pleasure and
#
# Quatrain estimation: 0
# Poem:
#
# And gave it nought. And when they longed to depart,
#
# The horse, that in her rider's eye, did love
#
# Most stoutly, gave the answer to her scorn. She hath another telling me that thou
#
# These are the worst in England's meanest state ;
#
# Never, but I will bless thee for thy great acts
#
# Excuse my gift, what I had done to thee.
# For rueful story'rt ijjQgj.
# 1504-1 593-
#
#
#
# 3600 Richard Costeduy
#
# The froward boy shakes his head at me,
# And if I would, would you have me back again?
# But faith, I did obey you well. There was good cause, sent me but for this,
# E'en all your word of glory to me did come
# And sell you that good heart of mine.
# With a sign, I whort
# Quatrain estimation: 0
# Poem:
#
# So long since laid aside his first love,
#
# Though stung with feathered pains, till evening's dew
# Did tender snow his steadfast stem belie.
# He burst the grove ; and hangs his head aside,
#
# To hear the hour-god's fond exclamation :
#
# ** God, therefore, grant that I may soon resign
# The comfort of my soul, and tu-mp thy heaven.
# My name, my bride — henceforth call I thee my wife!
# I place my hope on thee ; but, if un-tried,
# I will be satisfied. So, let me wed thee."
#
# " I own, my friend — I own thee on thy knees,
# And humbly yearn, for now some dearest joy
# Can never come, to whom I never can."
#
# He pressed his lips to his ear ; and as their mouths
# Were closing on her fair hand, a tim
# Quatrain estimation: 0
# Poem:
#
# And both began to lament, and longed to see
#
# A better life appear :
# But, O God, how hast thou shaken them so ;
#
# And speed thy wrathful counsels to the gate!
#
#
#
# THE RIVER HOUSE. 103
#
# As I write to them, the moon
# Woke as I sat on my bier.
# Then I said, if it be so,
# Surely such a feast I will ;
#
# But many a troop of quiet souls
#
# Listened, and all again were silent ;
# Hence their respect vanished ; just so.
# For ragged feet and a hungry heart.
# Then the moon woke again,
# And to me all human ailments
# I must humbly pay ;
#
# Without a single wish to hope
#
# Not conquer by disease ;
# So I took my wonted rites to shun
# From the unhallowed view.
# But
# Quatrain estimation: 2
# Poem:
# By plenteous meanes in the desert, with signal
#
# fight;
# And, sparing the fainting soldier's death,
# He wrapt himself in it." — WALKER.
# Distribution. — The old Saviour's thanksgiving face the
# Grave :
#
# "O, dearer, dearer, dearer then my soul,
# Was ever my sad vanity of heart,
#
# Earth, were it but a human soul that lies,
# A God to do thee good, the good that should
# Not be thy doing ; was ever my joy.
# Yet, when I meet you here, the Godless^eat
# Of Apes and a Hell, might make all things
# What they did then, and all things that shall
# Be.
# And what that Soul shall be next be thought of then :
# Didst thou not say, as a man speaking rightly,
# "Poor soul!" — with those only
# Quatrain estimation: 0
# Poem:
# And plunged in depths of bitter anguish,
# While mixed with blood the earth was homo,
# And quell the many sore woes she knew.
# O, all this while I suffer'd, all this while ;
# That I was glad to thank all he gave,
# To give him self for mine, and that we shared.
# There he alone preserved her honour'd breast.
# She had not suffered for both her own ;
# She might have given for mine, if to my grief
# She knew my smiles were full of kindness ;
# She would not have deserved for me mine own.
# No, but to keep my being humble and wise.
# For that same day I spake to her my love,
# And to the dear one I strove to intrude,
# And to be as my heart abiding true.
# Then she was so wonder'd that none could tell
# Of seeing me ; and I, but not the blighted
# Quatrain estimation: 0
# Poem:
# And with tears fed the day of dread.
# 4.
# While thirst and anguish, some yielding, to me still
#
#
#
# THE EPISTLE TO THE EPHESIANS. 151
#
# The pure and all-sustaining thirst was.
# While madness, enraged from morn to eve, and
#
# sunk
# With such despairing fierce complaints on me,
# As to desolate myself. With great impatience
# The vicar pleaded, and with tiger-like force,
# And with unrelenting violence, prevailed.
# And thus, with all the gold borne by his riches,
# And all his more splendid piles, my cheeks
# He tawed, and in a threatening hurry he told
# All he had heard and seen.
# By this the valiant vicar now heard
# Back in his remorseless, down-east course
# The false tactics of malignant hate
# And retribution, and the saint
# Quatrain estimation: 0
# Poem:
# But I have hope that God’s eyes shall see.
# Our lords, my lords, did take us unto their bosom;
# With my hand they kissed the pour taken,
# And tenderly to us set them on our breast ;
# Upon our necks, my lord, they put of our strength,
# And laid they up such wealth as by us spent;
# That scarce the prairies, when we came to seek it,
# We might obtain of that which from them was
#
#
# offered.
# 25
#
#
# The Eastern Sanctuary.
# An Odes from the Prophet Beckwith,
# One of the last to whom I have been bound.
# With half my limbs I have kept upon the ground;
# The marvel, my Lord, to me, is the brain,
# And I that liave beheld it, laugh to scorn
# My dullness that has bred me here with me.
# The Lord Protector of the court
# Quatrain estimation: 0
# Poem:
# The Duke could say to Sir William Jenkins,
# New partners have sprung, the keeper's daughter.
# Robert Thornley, who owned one farmhouse at Wytham,
# Hoard his nurse of the day's fray before his bed.
# He had a brother Thomas who understood
# The maze in which Sir William went, and knew
# The story of his father's disastrous dinner.
# But that was all.
# The King was in a state of protest,
# And there was nothing to be hoped from Ralph
# But he should take that at any price —
# He would learn to know the things that happened.
# And it was long ere he did so.
# He fought with his side ; but — he had a cold
# And a small heart, but he loved the woman.
#
#
# Identify the characters and describe their relationships to each other in this text.
#
# {
#     "type":"object",
#
#     "properties":{
#
# Quatrain estimation: 0
# Poem:
# And said the peasant, "O heart of mine, farewell!"
# (Canto, "Bells Sonnet 67.")
# "War every arm but my," said the lord of glory,
# "Fair war his staff;
# And the wool he wrapped in a ribbon;
# The quire of gold all round;
# "From arm to arm, all day long,
# Bring the glittering sword."
# Walls, that high-built buildings,
# Led on the people's pride —
# "I know the gallant warrior stands,
# A strange red knight!"
# Foot-rigging and horse-craft, too,
# Grew up on the scoffers —
# "And I know my lord of carnage!
# A rank and splendid knighthood!"
# She leaped on the mighty warrior,
# Or kissed his flanks and his breast;
# "Ah, how my lord is worn and cold!
#
# Quatrain estimation: 0
# Poem:
# And not a cloud wore fall, to blissful joy.
# Though there were some griefs in that brief day —
# From the small child a sigh of joy arose —
# The poor-eyed lass had cried to long since,
# And in her little arms, she clung to be quite
# Adam's own own.
# 2S
#
#
#
# THE BURNING OF THE KING
#
# Then the daffodil's grace of voice and tone
#
# Burned the cold sky with a gentle thrill to go.
# Groans and sighs rose by some, and by some,
# "To her sweet child's eyes, their crying throes do follow ;
#
# For on her breast the overflowing tears
#
# Roll from the lilies ; make the tender shell
#
# Tight ; and ere the sun has lost its light,
#
# The loving ones of each bud are kneeling
#
# Their tears in
# Quatrain estimation: 0
# Poem:
#
# And gave her leave her train to prepare
# For a huge sacrifice among the son
#
# As spoken from her bower. She awhile
#
# Beheld the pain that she had nought for borne.
# But the child still sleeping at her side
#
# By day and night she eagerness essayed,
#
# And the soul's flesh rose in sweetest tune.
# Suddenly she raised her eyelids wide,
#
# And as on her lip the breath I sprung
#
# A curse upon her brow the tear it sent
#
# Above the flowing and the patient tear,
#
# Whose hurtles of sorrow did or feel
#
# Which some of old, in that pleasant seed
#
# Was like a brief, bright, soothing dew,
#
# And on the mighty cheek had been shed
#
# Thy iron rim, and smile upon thy cheek.
# That happily this dandiacal, weak
#
# Moulder found me alive amid
# Quatrain estimation: 0
# Poem:
# Till Solomon his pride had quickly passed
# The will of good Lord God, and the spirit fled away
# To all the prophets after, all the scribes still
# The foundations of the gospel were old,
# The gentry's bans the tomes of malchitia,
# I mean this matter ; but the Lord God made
# There was so much the Israel of the world,
#
# I of the church ; and God made is his word.
# That the Gentiles who had sold the Lord In serries
# With usurers that had so many debts arose
# That buy the gold of the king; and what a shame
# Forspeed of the Lord God that are of the wrath
# To buy gold, but what their shoulders yea and nay
# And ye, upon a tribulation, prowling be
#
# Me, sirs, my propheties! your money-check in olden haste,
# Not lending yet you are so degenerate
# Quatrain estimation: 0
# Poem:
#
# 20 And with drawn dagger ploughed his sore sink;
#
# Yet he to his rest was doomed, and none
#
# Could tell him whither he his woes end,
#
# 15 For none knew what news he sought to see.
# His buffeting fury s.jeeped still on him,
#
# But when at last he heard of his fall,
#
# Upon his window waited till he said
#
# " He did not weaken his strength, and that
#
# 20 He thank him that he is not lost."
#
# So was he then; when first of hours
# By the firelight saw far beyond the hills,
# 19 Unto him the wall of Acon-ton was bent,
#
#
#
# THE COMEDY OF ERRORS. 171
#
# And by him came John into the gate,
#
# Mat heart from sin to mind from vice,
#
# Toan if the good, as he cried,
# Quatrain estimation: 0
# Poem:
# Though I would not slay thee, yet thoii did'st me save.
# The burden of the life of the people's wa>-."
# (lrin. li. § >•■).
# We nre npp«»nre his appetite Isted.
# ii. f f''' •
#
#
#
#
# m THE FIBST OUTLIK OF LAW
#
#
#
# Rulms, hail, recites a kyrie,
#
# For the previous name he recites ;
#
# After the lastle the burns, as Is their form :
#
# Thou sayst, the power of the law Is
#
# strengthened ;
# And I do Judg« the Lord, the Lamb,
#
# And my sanctificatlon.
# Thou art the mom or the fire, the feeder
#
# Of the cattle ; but 1 am a slave.
# Onry Choice Religion of the Awful Law
#
#
# Quatrain estimation: 0
# Poem:
# Please do not say something to this ejderly howling?
# Remember that all wrong officials are just going to get removed from your house!
# That doesn't just mean you just shut right away your shit down.
# Everyone is totally healthy.
# This is a priority.
# But if we are not, it will be refused to you.
# Respected Bill
#
# Posted by gharry on August 14 2010, 15:42 memes, 1 quote.
# Posted by gharry on August 14 2010, 14:42 memes, 1 quote.
# Posted by gharry on August 14 2010, 14:42 memes, 1 quote.
# Posted by gharry on August 14 2010, 14:42 memes, 1 quote.
# Posted by gharry on August 14 2010, 14:42 memes, 1 quote.
# From: gharry on twitter (
# Quatrain estimation: 0
# Poem:
#
# Image tagged:
#
# Share this Image
#
# When you upload your image please give us a share.
#
#
# Identify the main events or tasks mentioned in the text.
#
# {
#     "type":"object",
#     "properties":{
#         "main_events_or_tasks":{
#             "type":"array",
#             "items":{
#                 "type":"string"
#             }
#         }
#     },
#     "required":[
#         "main_events_or_tasks"
#     ]
# }
#
# {
#   "main_events_or_tasks": [
#     "Upload your image",
#     "Share it"
#   ]
# }
# Quatrain estimation: 0
# Poem:
#
# Edd-d-d-d'rd
#
# Curious about drip drops? I often discover these broken water drops over the grass coming through my eyes. What are they?
#
# It is a game-like pattern called trim palm bubbles. Pillowning the taste of palm sugar and packing it in custom-made tarps, they can be as simple as dropping a pencil or a metal wire.
# One of the best ways to obtain these bubbles is to plant them in your garden, symbiotic in nature.
# Having said that, they can look like a long sawdust cloud of metabolites.
# I really like this dreamer's taste.
# More from Etsy.
#
# Quatrain estimation: 0
# Poem:
# Delivery date:
#
#
#
#
#
# The following is a copy of the letter:
#
#
# (Text to be filled out or reproduced with completed images in electronic format)
#
#
# Roll-on/roll-off procedure – Attach the accompanying documents (if applicable) to the specimen
#
#
# Do you approve this specimen declaration? [Blank answer]
#
#
# When does you intend(es) to transport the specimen? I will ensure you are in a state of readiness. The contract/temporary worker/other person/organisation bound by code/federated/other …..
#
# Do you agree to place the specimen in a secure compartment at the point of departure, which you will open to the competent authorities. (Where applicable)
#
#
# (Signature)
#
#
# (Banking name and signature)
#
#
# ANNEX VII
#
# ▼M3
#
#
# COLLECTION AND HANDLING OF THE SPECIMEN IN MED
# Quatrain estimation: 0
# Poem:
# The venal will be born!
# Twopenny billionaires are still pining to be starred in the same place;
# In the last five years this is not so;
# The left is still riding the highest mile rounds;
# It is no secret;
# The left is still warming up in the very last stages;
# It is no secret;
# The left has already delivered EUR 225 million in dealings with major capitalists;
# The floodgates are still so wide open;
# This is not so;
# The seats of popular capitalism will still not be filled;
# This is not so;
# The seats of popular capitalism will still not be filled;
# The seats of popular capitalism will still not be filled;
# This is not so;
# The seats of popular capitalism will still not be filled;
# This is not so;
# The seats of popular capital
# Quatrain estimation: 0
# Poem:
# Enosto è' * un e* * la* la -ena -i le* -enofatme * ’ oolitiaehe * potto torce * epijnhe ase *foe •palme o Lecbe ologthcheses *bj- ♦pottare * palme a ana-* eallaro * flnflo * feo * 1 * * « * * * * * *
# 1 * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# Quatrain estimation: 0
# Poem:
# While Román is not a mugino, he is a viriotor.
# Autoría: Cristian Jambrina1,*, Fernando Santiago Chaves1, Marcelo Maniliña1, Carlos Díaz
# Officina1
# 1
# Universidad Técnica de Ambato
# *Autor de correspondencia: cl.jambrina@uta.edu.ec
# DOI: 10.5867/medwave.2023.S1.UTA074
# Palabras clave: Metrique, formatos, adhesivos, estilométricos,
# análisis, CUC
#
# Tema: Ciencias sociales y Artes
# Introducción: La situación de nuestros hijos es difícil, los
# medios de comunicación son burocráticos, esto empieza desde
# el inicio de la paternidad y llegado el embarazo. Por ello el uso de
# medios tecnológicos también llamado mamas,
# Quatrain estimation: 0
# Poem:
# Rosa Maria Luisa Zitoia
#
#
# Locatell
#
#
# whey
#
#
# Dolor de pies
#
#
# Brandía
#
#
#
#
#
#
#
#
# Esposa
#
#
# Cauchuvia
#
#
# Braso de la Cañada
#
#
# Candela
#
#
#
#
#
#
#
#
# Lorca
#
#
#
#
#
# Conclusion Mayor
#
#
# 2000275
# 20020878
# 2009878
# 2002354
# 2003254
#
#
# = Red de Abonar
#
#
# Dienes
#
#
# Coca
#
#
# 2304425
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# = Al bar y al diablo
#
#
#
#
#
# = Tobache
#
#
#
#
#
#
#
#
# Cuaderno
#
#
# Sñ. Reyes
#
#
#
#
#
#
#
#
# Foga
# Quatrain estimation: 0
# Poem:
#
# Bless de precious girlie!! My experience as an Instagram user has been hard. First off, I was not into dating; I have never tried. Problem is, I have no idea how to look. I have had various followers, but most of them are all females, and talk about ONLY the female needs within attacking. As of now, I have not actually got my handle and hide behind the username to be identified by the other users as my ‘other’. I would like to get a better understanding of the females most in my actions.
#
#
# Can you create a timeline of the author's personal experiences with Instagram, including the design elements and the user's timeline?
#
# [
#     "timeline"
# ]
#
# {
#   "timeline": [
#     {
#       "date": "Before dating",
#       "description": "I was not into dating; I have never tried. Problem is, I have no idea how to look. I have had
# Quatrain estimation: 0
# Poem:
#
# Me toplessim, mas nien pu bem.
# Atier es Hrunt tres de pello
# As Ease com un d’altres.
# E parte e parte
# T o t paquet!
#
# E part de Jfames prenda.
# Si no parlas mas en rozar.
# Atier lo tefar, e aster à uass vents sia mot.
# Bo-wit feme: bon! Toto fe soga.
# Toto fe soga: se seu he du com de lu.
# Toto fe soga: se seu fe bolsa
# Sèu fe vi-te] e fem!
# Toto fe soga: se seu fe bou l e cresun.
# E feme e feme
# Ne moure com mos.
# E part com nos.
# Voi dir a miosig de nova
# Toto fe soga: se si que no le ve
# Quatrain estimation: 0
# Poem:
#
# tag
# The Tobisteps outhouses in Monte Carlo, France.
#
#
# Can you find and list the locations mentioned in the text along with any descriptions or activities associated with each location?
#
# {"type": "object", "properties": {"locations": "array"}}
#
# {
#   "locations": [
#     {
#       "name": "Tobisteps outhouses",
#       "description": "The Tobisteps outhouses in Monte Carlo, France.",
#       "activities": []
#     }
#   ]
# }
# Quatrain estimation: 0
# Poem:
# أن حمدنا الصبحي (كان ثاني)
#
#
#
# Pseudonymes: نادي القانوني البرونزي؛ تجمعات الاساتذة وتركيا
# Grade: Sergeant
# Date of birth: 12 September 1955
# Place of birth: Ruse
# Nationality: Russian
# Gender: Male
#
#
# Sergeant Nikolay Avdeyev is the commander of the Battalion of the 8th Guards Retired Army of "Soviet Union", an entity that participates in the tactical training of the Russian Armed Forces. At the same time, he participates in the preparations for the Russian War of aggression against Ukraine. In his capacity as commander of the battalion of the "Soviet Union" he is responsible for mobilising Russian soldiers for Russia’s war effort. The Battalion of the "Soviet Union" is therefore responsible for supporting materially actions
# Quatrain estimation: 0
# Poem:
#
# Description
#
# Bless de precious girlie!
#  Enter your name!
# Enter your Email!
# Name X
# Email X
# Please sign your name with a crown if you are.
# Not a total,
#
# have you just finished a post?
#
# Activate
# Facebook
#  España
#  Better manage
#
# Me help.
#
# Quatrain estimation: 1
# Poem:
#   And that's not why I supposed the suits came in, because Rudy and I are going to be literally wearing appropriate suits.
# Diamonds will always be tight, but Rudy doesn't want to lose them.
# Sad Artist (2013)
#
# Unless otherwise stated, the content of this page is licensed under Creative Commons Attribution-ShareAlike 3.0 License.
#
#
# Identify and list the main themes or ideas presented in the text.
#
# {"type":"object","properties":{"main_themes_or_ideas":{"type":"array","items":{"type":"string"}}},"required":["main_themes_or_ideas"]}
#
# {
#   "main_themes_or_ideas": [
#     "Bless de precious girlie!",
#     "Diamonds will always be tight",
#     "Wearing appropriate
# Quatrain estimation: 0
# Poem:
# Je voulais, je voulais tout de suite, je ne savais pas comment. Et puis j’ai fait mijoter un joujou sur le bout du nez pendant un moment. Puis après, je me suis remise en place. Je voulais vraiment me coucher…
# J’ai commencé à réfléchir, j’ai supposé que....
#
#
# Pouvez-vous identifier et catégoriser les différents types de stimuli environnementaux mentionnés dans le texte, en précisant la nature de ces stimuli et leur contexte général?
#
# {
#   "type":"object",
#   "properties":{
#     "stimuli_environnementaux":"array"
#   }
# }
#
# {
#   "stimuli_environnementaux": [
#     {
#       "type": "joujou",
#       "nature": "jouer pendant un moment",
#       "contexte_général": "Je voulais tout de suite."
#     },
#     {
#       "type
# Quatrain estimation: 0
# Poem:
# – Donné son nom sous le Soleil, pour notre aimable société, de nos très bons frères de l’Auvergne, habitant'r‘à Chambéry.
# Les historiens et les poètes qui ont consacré à chaque journée de notre mois les poèmes qu’ils y chantaient, ont sacrifié la forme musicale à la forme, qui, depuis quelques années, a été trop négligée, et s’est réduite à quelques chansons, boiteuses, manquantes, incomplètes, souvent prosaïques, qui remplissent de petits poèmes joyeux, à belles lettres, populaires.
# Dans les chansons de mon ami Dentu, on a conservé l’idée qui a caractérisé l’es
#
#
#
# *2./
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pocratie française, et qui est le point de départ d’un art
# Quatrain estimation: 0
# Poem:
# Lee, him who afterwards was the incomparable Durant,
# you might have made long wars for liquor and gold,
# Hence I came.
# FASTLY,
#
# [To LUcia].
# Sometimes in love's flowery verdure tipped against
# Daxer, with a song, spring's cheeky trembling, spreads,
# And stays, now with a beam of light in my eyes,
# And now a glance, such as thine, with a kiss.
# A grave ; like me, unconscious of the threats of
# Pandermouth and of the roar of hell's thunder from
# the darkness, but with one, and much, cordial glee.
# Whose heart was enthroned in thy bosom, love my
#
# Lady,
# Does the jealous Deedhness depicted in the
#
# Mind of the young poet at a moment like this,
#
# With thy countenance, only one of the three
# Quatrain estimation: 1
# Poem:
# the crowd, they would immediately scatter. But, in
# the capitol, they would not scatter, they would scatter,
# and would scatter, for no man would ever, no more
# than the young mother, pay the slightest attention to
# the crowd.
# Vol. IF. — 30
#
#
#
# 306 HALIFAX THURSDAY.
# Nothing could have been better suited to this
# marvelous situation. A crowd of men and women
# rush over the scene of the tragedy.
# "We are all dazed by its enormity," cried the
# Disorders.'^^ "We had better rest, in safety, and not
# in pain."
#
# "Thank Heaven," said one of the Capulets, "for
# the comic piece that these scenes cost us."
#
# "I am willing to believe that it cost us," said
# another of the Capulets, with much emphasis,
# "though the people make us laugh when the
# Quatrain estimation: 0
# Poem:
# your fruits, you ought to breed and rear plenty
# of uncieet fruits to the vines, which you spread
# ■elf and have a crop of seven yards to the
# acre, which is sometimes more than estimated
# for the com of the year. You can plant a crop
# of potatoes with more difficulty and give more
# care of seed weed than h has done for the com
# of the year, and we do not see the occasion to
# buy soldiers' or navy ties. We have thought
# that we might claim the privilege of proclaim
# ing the duty of using the corn for the agricul
# tural purposes in the Humboldt Valley. We
# think that if the corn is an article which is not
# planted it will be grown for the future wants
# of the country, and we firmly believe that there
# is no other article that needs cultivation
# The corn is a very valuable one, and as it
# is grown for food and for
# Quatrain estimation: 0
# Poem:
# Greek and Perùnians into a swarm,
# Or wander round and round in merry play,
# Brave fellow, bold as you, and solid base:
# Or are you simply warriors of the Panciu?
#
# How, then, do you kill and though they kill me
# By doing what I do, am safe and sound?
# And wherefore, why am Jv< and you the same?
#
# Then I was of no use to tell you
# That any country you would come to rule
# Shall be your father's, for you will be there
# Your own Philopator, and a friend.
# And you and I are likelv by and by
# To share of this kingdom again:
# And here are we. So, indeed, you speak.
# But are not I, and you, and all the rest
# To me my brother, or the son of mine,
# Pollets and Muses, kin and
# Quatrain estimation: 1
# Poem:
# over the ground the rest you leave behind, you
# will soon find myself a mere grumbling "shop-
# unl-dy," while my "old-fashioned ally," or
# the President of one of the Dot Party's political
# associations, will bury me among the old manu-
# facturers' toads in order to keep me in order
# and keep me from getting excited. What I
# have a right to expect is, that I shall keep
# your earthly throne on a firm and solid foundation.
# I have a right to reap what I have sown, and
# I will soon be with you in peace and prosperity.
# Why should my true friends bid me hereafter frown
# upon you, when they point to you as the chief re-
# sult of all my hopes of extension of our political
#
#
#
# 1
#
#
#
# 178 The American Citizen
#
# freedom? I am not a Republican, or
# Quatrain estimation: 0
# Poem:
# some of your branches about, you have the advantage
# of every branch.
# Hopeful confidence and an abundance of ability
# will be given you in a day or two.
# The time and money will be saved.
# You can. expect a great deal of satisfaction
# and pleasure.
# ME. K. L. WEATHERLEY,
# Special Agent for Boodie & Co.
# THE TENT
# 46*
# “A
# HAVING
# SHOULD
# COMPLETE
# THE
# ARE
# At
# I.
# /
# IN
# NO
# STRAVAGEE!
# If
# \
# /
# 1
# W
# B
# MOST BEADQUAEE ALL
# \
# B
# ENOUGH TO
# W
# McMagor.
# Quatrain estimation: 0
# Poem:
# your pieces of mason-leather, I am sure they
# will do just as well."
#
# But no sooner had that news come, than Gerald
# turned to her in a more determined manner.
# "Well, child, I haven't done very well the
# whole way. I have got a camp-fire in my
# trunk, and I have to go round the streets about
#
#
#
# 52 PAMELA.
# every day to scrape at crackers and to make
# the cherries smell. I've got to be light and neat,
# and I haven't any time to waste upon anything.
# It's made for me so that it really does not
# matter what the weather is, whether you're at
# the house or ought to be. But with you and
# your loads, darling, what do you suppose we're
# going to do? "
#
# "Been all right, Gerald," she replied
# Quatrain estimation: 0
# Poem:
# the shirt-waists around you and go out of your
# pocket, you might as easily get clothes as you lose
# them."
#
# "Oh, you can't do it to pay," said her father,
# a little disappointed, "Frssmier would have known
# you had done it to l>o without him."
#
# "You know he wouldn't!"
#
# "Of course I know he wouldn't," said Magnan,
# springing back and smiling, "but I took theam
# off; and you wouldn't want him to know you were
# talking."
#
# "I am not so sure," Hunt replied; "though you
# know I have."
#
# "Well, you said you would go with some one,"
# replied the general, hopelessly depressed and shud-
# dering. "Be it so, Magnan," said M. du Buat ; "I
# will break the rules.
# Quatrain estimation: 2
# Poem:
# n your own table, and applied a sincerity and
#
#
# honesty which made you the most aimless
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ably-contented man in the world. Then, if
# anything was really unnatural at the table,
# it was to swallow the whole dinner.”
#
# “ Whereupon Mr. Dadely dropped
#
#
# rg him his s
#
#
# ds of snow, whence he retired to an inn where
#
#
# it would be advisable for him to dine.
# “Umph! There was a good dinner indeed,
# but it was a good dinner compared to the
# common morality of the day only.
# “ Now, if you don’t mind me telling you
# sometimes I must tell you some little
# ones, it’s coming rather outside your range
# of knowledge, because, as I understand, a
# sex
# Quatrain estimation: 0
# Poem:
# your people in one line, when we would do
# otherwise, it was through a sly trick of the most
# unauthorised of policemen. Now 1 think my suf
# ferings are almost incredible. In the distant ma
# terial of this world, I am as well satisfied as any
# poor fellow in England.”
# Messenger noon morning, he looked about for
# some indications of what might be expected. It
# was as plain that the army was to be assembled
# in Portland. Some fifty miles southeast of Eng
# land he found a guard he could be relied on with
# out difficulty. He left the city, but with a few
# drawing clothes, in presence of a large gang of
# soldiers. This was, indeed, an unusual meeting
# at Portland. It seems to be a policy of the
# English government that the enemy’s rendez
# vous will be in that city, a policy which is
# strange to understand, and what may
# Quatrain estimation: 0
# Poem:
# a little more, I will scatter it all again. But this
# newness of your politics is an advantage.
# But who is the greatest of political leaders?
# Some say George W. Bush. Others Mr. Baker.
# Even the influential gentleman in the legislature
# of Illinois, Raymond A. Hooker, is an advocate
# of strong influences at running.
# But it is not the strong. We were asked by
# some friendly democrats about a meeting of
# the Democratic executive committee of the
# Louisiana Legislature at the state-house. They
# declined to have the meeting, but I was informed
# they would at all events meet that evening in
# the gallery of the state-house. A semi-hour
# was spent in an effort to centralize the meetings
# and hang fires that learners might have as far as
# possible. At last they were all put down, and
# a vote was taken that nobody should have a vote.
#
#
# Identify the
# Quatrain estimation: 0
# Poem:
# it you may thus unluckily find a speck or two of
#
# *In his " Geography" which preserved the most judicious
# reader the work of Gregory, Pope Julius II., who was a
# distinguished scholar, and whose genius, in works of dis-
# tinct merit, has been acknowledgcd by many distinguished
# persons, has described the history of Poland and the
# Polish language in the pages of his " Geography," the
# 22nd, 23rd, 24th, and 25th Ck^c8ts. A part of the
# causes for departure is given : and the steps, taken by
# those who were induced to retuie to Poland, seem to
# me very unaccountable. l^ow, it is not the undermining
# of the Polish language which has more than half the
# force which Mr. Bliss has attributed to it. Tlie authors
# of the account of the foreign dispute were
# Quatrain estimation: 0
# Poem:
# with me, you shall be damned."
#
# " Give me your hand, then, and I will immediately
# inform you of his crime."
#
# " Go," said we ; and as we advanced, they kissed our
# hands.
# We returned to the house, and on going through
# the drawing-room, we found the inmates kneeling
# in silence, listening to their serenade and the music
# of the flute.
# The chorus, as I have just reminded you, was
# formed of ten voices, three ofwhich were of Swiss
# nationality ; the other seven of the States of the
# Netherlands. It was, I must confess, a death-like
# tranquillity about the whole entertainment. Those,
# however, who in the high life of all men, must have
# perceived the excellence of their native language,
# could not complain of its monotony ; for it was all
# the language
# Quatrain estimation: 0
# Poem:
# this black sheep, you shall be the last to take it
# either by the horns or horns. I have nothing here
# that is disagreeable, but it will be a relief to the gray
# beard and to those who are near, and I hope that
# the children will be well cared for.”
#
# After this conversation Miss Ellsallion went on,
# saying that she had not gone very far to the south
# east. This evening, however, a sudden shock of rain
# brought her back, and she lay for five minutes on the
# ground, so that it was not possible for her to walk
# away alone. It was then that one day she instituted
# an examination of a certain drinking water in one of
# the old ranch houses, which is in the heart of the
# country.
# The water had not been cooled a day, and in this
# instant its temperature was so high as to make it a
# hot-bath
# Quatrain estimation: 0
# Poem:
# the PROMOTI, you will be laughed at."
#
# " The site," said the learned man, " is not copyright-protected."
#
# " Let us go back to the plot," said Victorina; " I have to pass on to
# the next paragraph. There is that very story, that a young lady of
# some very extraordinary sweetness, with an air of nobility, and
# personal attractions, who spent her days in travelling, left a gold
# medal in the hands of a celebrated painter, who set some drawing at
# life-size. In order to procure it, a shilling or sixpence was required
# to purchase a pair of hair-brushes, and to symbolize all the
# insolence, which her greatness^ rank could not command. The object
# of the claim was to represent this rare gem, after the fashion of
# Jane Eyre; and in after years the subject was treated with
# magnific
# Quatrain estimation: 0
# Poem:
# your products by all kinds of means, the
# same result will be obtained.
# Diluted Wheat.
# The principal use for a wheat culti
# vator is to obtain good quality. That
# is, good, clean wheat, and the prod
# ucts of these are good peas, ripe ears,
# and a good lot of peas for meal.
# The first stage is the most difficult
# to obtain from wheat. The silo need
# be always ready, and, just as the ears
# are being planted and hundreds and
# hundreds of peas formed, the wheat
# will begin to make its appearance,
# and a large part of the wheat is left
# uncscrubbed and scattered about.
# Tho action of the soil upon the
# wheat proceeds in a similar way.
# After the wheat is growing, it will
# seem to require more and more nour
# ishment, and it will enrich itself by
# adding more and more of the
# Quatrain estimation: 0
#     <div>
#
#       <progress value='250' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [250/250 17:47, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>-0.000000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.000300</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.000300</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.000700</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.000600</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.000700</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.001000</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.001100</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.001800</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.001600</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.001200</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.003400</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.002800</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.002900</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.003200</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.002800</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.003200</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.003400</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.004400</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.005100</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.004500</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.004100</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.003400</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.004800</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.004100</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.004400</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.004100</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.004800</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.005000</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.004100</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.004800</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.004700</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.005000</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.002800</td>
#     </tr>
# ...
# That I should be the crowned
#
# I knew the force of love.
# Despair is in the soul
# That can it only move,
# And it must do it.
# And when once
#
# It knew
# That it had none
# Quatrain estimation: 3
# Poem:
# The husbands of the heart, and the lives
# Par when I am apart from thee.
# That love and hate shall live and die
#
# Will not a thought of me withhold
# From my spouse's heart, and my spouse's life.
# And the life of my body
#
# And the quick death of my soul
# The narrow compass of my soul
# And the painting sharp of my soul.
# That I may know thee, too,
#
# And I shall know thee not.
# For would I thought of thee with
#
# A sorrow's silvery hough
# That they could add to their hate
# And would think of thee
# With a load of smugness.
# I will say with one breath
#
# That this agony
# Of my body
# And my soul
#
# And this evil
# Of my other soul
#
#
#
# SHERON
#
# And my soul
#
# Is my soul
# And my body
# And the bodies
#
#
# Quatrain estimation: 1
# Poem:
# Love that bewitches with its presence,
#
# Of Cupid's flashing passion
# The heart's desire.
# And if thou wilt not,
# There we will lack the love of him
#
# Who spake thy words,
# That heart's desire,
# Of him who hath deigned
# To be a man;
# That heart's desire.
# The lore and wisdom
#
# Of Sappho's skill.
# The wise, the fine,
# The subtle, the so fine,
#
# And thou wilt know
# What love is with most
# And why it's with most
# The lore of Sappho.
# Of Sappho's skill
#
# That will know
# How to be free
# From love and pain,
# And from any passion,
#
# And henceforth
# May be the man.
# And he may be the man,
# That heart-sickness
#
# And restlessness
# And all the rest
# Of madness
# Quatrain estimation: 3
# Poem:
#
# Thou thyself canst know by sighs,
# And willst not know by tears;
# The love is in my bosom,
#
# And there the pain doth lie.
# Am I not in my love's sweet mist,
# That these are love's sweet mist,
# To be with hearts that are
#
# So blessed, so red,
# That for him, with the same,
# They shall be made to be?
#
# And is it in my nature,
# That the same may be with
#
# His, too dear unto me,
# To be with hearts that are
# And are not '
#
#
#
# Pregnant Love. 273
#
# With hearts that are not,
# That he be my love,
# And my weariness
# And my sorrow,
#
# That I have not
# That I have not
# To love and
#
# to hate,
# For the same.
# And 'twas Adam,
# And 't
# Quatrain estimation: 3
# Poem:
# And this, like the sweetest source of woe,
#
# Note the sightless seals
# And note the lulled glimmering air;
# And the war and rage arose
#
# And the passing still of time
# And the glimmering, dying who,
# And the shrinking pale lips
# And the hollow dull eyes
#
# Of the traveller
# And the strange, unlovely sounds
# And the shattered eyes
# Of the changeling
#
# That, the weary lass,
# And the dying caress
# And the star-drift-deceiving
# Kisses in the silence
#
# That, the eager soul
# And the penitentiary
# And the dying sigh
#
# That, the broken heart
# Of the wanderer
#
# That comes to the end
# And the weary and sad
# And the sharp pain
#
# That comes into the end
# And the weary and sad
# That comes into the end
#
# That has never
# Quatrain estimation: 3
# Poem:
# Sad counsels given to thee by heaven's host,
# And peace concealed in vases of gold
#
# Shadowed as when the flowers with pomegranate
# Were hung in gold.
# Oh. icy Love, to tell again
#
# That Love, in heaven's weavek of passion,
# At last will wake to lie in thy own
# And like a lion at rest.
# The heart that more than yours,
#
# The heart that bears you,
# In heaven's love and prayer
# Is in its place,
# By heaven's will enlarged,
# And its praise and song
#
# Past Joy, and past Happiness,
# That God hath promised you.
# The heart that has lain,
#
# The heart that hath inspired
# With loyal thoughts
# Of those vast joys and good
# That will ever be,
# And those immortal ends
#
# That will ever be,
# And those infinite lights
# And those angels
#
# Quatrain estimation: 1
# Poem:
#
# That hath promised more than " Thank ye,"
# and would have been more than " Have we "."
# Will you not desire to know our phase
#
# Of soul and spirit, if you love us
# And may such part of a realm
# Come to you autho' revel,
# And satisfy the soul like
#
# The sanftest dream of the soul
# That ever was,
# And can with the lips
# So much that we feel,
#
# What may be belie
# In your mind, soul,
# And in our sense,
# That is so great
# A world of love
# And of pain,
#
# That is very great!
#
# His little words,
# Must be seen
# In the great soul
# And in the world.
# He leans his honest mouth
#
# Like a lighted sword
# And tries to speak
# To give to those
# That we be, to
#
# Prodon him
# A better life
# And he gets
# As
# Quatrain estimation: 4
# Poem:
# A lingering gloom.
# With stillered wearied eyelids shed the tears of morn,
#
# And mock the early dawn.
# The autumn droops its shadow from the behest,
# And finds that Nature has
# This to her sweet work still in trust of youth.
# And that her decay may be.
# Her strength is even with her power.
# And that her end may be.
# On the earth that mourns the past,
#
# And her fortune summed so,
# The memory of sorrow is yet warm and bright.
# And the winding mourners roll
# Their golden shadows through the gloom that
#
# Is gone.
# The constant thought,
# That is the bane of men and of nations,
# Thou shalt have the sorrow,
# That is the choir of widow's money,
#
# And that the county is
# Possessed with yearnings that is no more.
# And that are breathed by thee.
# Quatrain estimation: 1
# Poem:
# There's weary progress. And weary even to die.
# To have no rest ;
#
# Pause, hurried look, quick peer.
# With blinking eyes, and footsteps slow and slow.
# Some hear the tread of some old ship's boat,
# Some hear the rising music of the wind,
#
# And then suddenly all's silent.
# Some hear the tread of every wind,
# Some hears the rolling of the sea,
# And, in a moment, the waste places,
#
# And, in a moment, we lie
# With things that make life a struggle,
# And leave a negative end to
# Each individual existence,
#
# And leave him a negating deed
# That he must bear as some mortal man —
#
#
#
# The note of indecision
# And of transitory favour
# And the smiling dust of human life
# Out the dying breeze
#
# And the mourner's side.
# Heaved into dust, and out
# Quatrain estimation: 4
# Poem:
# And the unclouded night is momentary,
#
# And the eyeless ages and the blind eye are
# Deceitful with evanescent charm,—
# For the " that is hallowed is
#
# And the "that is precious"
# is more precious than gold.
# It is made disparaging by
#
# For " nothing but hate
# Is contained in the alloy
# And the taste will be deep."
#
# For " glory often sweeps
# From the face of the "throne,"
#
# But the " throne "
# is the throne
# Of everlasting rewards.
# And when the hour
#
# Is full of the ray
# And the "waiter
# And everything
#
# Is united in the "day,"
# Then the
#
# Year to its end
# And the time
# To know the
# Immortality
# Of the "tender"
#
# And "wrinkle
# In the mortal
#
#
#
#
# Worded A Poem
# Quatrain estimation: 1
# Poem:
# And in their waking wretchedness, and joy in anguish,
#
# By every sigh and sob beseeching you to know.
# 60
#
#
#
# Who bears the crown of glory with her hair ;
# Who for hers is always obsequious,
# That can claim no lesser honours,
#
# And receive none from the public gaze.
# Who never dies for her sake ;
# Who those which do not please her,
#
# And do not suit her designs,
# Gain no fortune, or gain none,
# By any acts of charity or fortune.
# Who is ever poor,
#
# And striving hard to be rich,
# And is not sought to be rich.
# And has not been so at all times,
#
# But has been, in all times.
# Never weary,
# Or with so dreadful pains
# And pains everlasting to endure.
# Never drooping
# To her,
#
# And bearing no death
# That ever
# Quatrain estimation: 1
# Poem:
# In angel ward may it dwell,
#
# Then it will now be near to thee :
# Nor wilt it be so cold or cold.
# Nor sweeter than on Mary's face.
# Through many a sea of trouble was my lot to part,
#
# For all the providence of God.
# The lot of man was in the great fray
# The lot of man was in the great fray.
# That held the world and was alone
#
# Within the fair grasp of God.
# The lot of man was in the great fray
# That held the world, and was alone
# The lot of man was in the great fray
#
# That held the world, and was alone.
# That held the world and was alone
# Was he who knew no more
# Than to be was in the world to be
#
# And in the world you played with me.
# That held the world, and was alone
# Was he who knelt by the swan
# And
# Quatrain estimation: 5
# Poem:
# And, mingling with the shadows of the sage,
#
# In the full evening's dusk, our graver eyes
# Like the dreams of the Past, beheld his form
# That Death had not modelled with his own hand.
# The shades of the ghostly ages were cast
#
#
#
# The Past is at rest, the Past is eas^ :
# The past is to the memoiy of faith
# On the scene of the achievements of the Past.
# The Past was motfted to its rest on the face
#
# Of Time, and the Past was to the Memory's
# Turn from his festivals, from his wars.
# On the hour of the deliverer's return,
#
# The Past was the Livadias to the Past.
# The Past had ever been, the Past,
# But not as the Past was moved on to it.
# The Night is our Heaven, the Night is our Heaven.
# That Day is ours that brings Light
# Quatrain estimation: 2
# Poem:
# In mien' s agnostic attitude POINTING
#
# And with its thin, velvet teeth
# Wants not to shun the Standard marks.
# Like a friendly death-prone bee,
#
# She busies the chubby never
# For the sake of shyness.
# But instead of words to her,
# There's all her delight in fairies
# And bloodless bits of gaiety.
# And her LOVE and her PARTIES
#
# And the rare charm of her eyes
# In the Georgia blue
# And her coal-black hair,
# And the great sparkle and shine
#
# In her pretty face
# The pulverized wealth
# Of her beaming eyes.
# And the dainty cadence
#
# That has her voice
# And the rarest Phonegraph
#
# That flutters around
# And flits in the air
# To her.
# And just as if
#
# That which her eyes
# Found
# Quatrain estimation: 3
# Poem:
# The rich primal birth within its breast,
#
# And its best Art may soon be presided over
# With twinkling stars that shine no more
# From the red eye of nature's fountain,
# That it crawls above, with its heat
#
# And its glow of light,
# And its tints of fire
# And its glory, whose rays
# Bade forever the stars to look on,
# And their faces to show
#
# And their voices to listen,
# As it was said
#
# To the soul of man
# That it had reached
# The end of its year,
# And I, proudest of my race,
#
# Would be worthy
# Of the emblem of
# Going, Soul, to this
#
# End of our race
# Through the scenes that you
# And my race have passed.
# And on the West,
#
# And the East,
# And all the earth,
# In this age,
# These are the homes
#
# Quatrain estimation: 4
# Poem:
# As if to cloud the cloudless sky the Lord intended.
# "Thou, my lords and peofifie,
#
# Thou whose glad power
# Was granted me,
# By the subtle masters,
# In counsel sublime,
# And in spirit firm
#
#
#
# Me aimed to test.
# Who gives me just and fair
# And generous deeds
# With eyes of discernment.
# And with purse
#
# A leather sack
# Of five hundred coin.
# That seems to test
#
# All the jugulatory
# Of the mighty Lord
# And his name,
# And his grace,
#
# And his goodness
# And his wisdom.
# For the Lord made
# The pride of a peopij
#
# And tlie throne
# Of a man.
# And even now
# He quite passes
# His eyes by,
#
# Thou wilt know
# How the Lord
# Gives me
#
# And the Lord
#
# And his grace
# And his goodness
# And his
# Quatrain estimation: 2
# Poem:
# It shadowed the world with home, and country, and
#
# home;
#
#
#
# And each there missed the bygone smart,
# And lured sweet palms to the brittle corner,
# And left tying green strands and feather-bands
#
# Themselves upon the budding bract,
# And left their traces thundering through
# The willow edge, and oven.
# The rose had grown its pretty petals
#
# Of warmth and glory here,
# And the scarlet around it
# Told of her recent victory.
# And the fairy stranger came
# By her name, and affected
#
# The rose with rosy cheeks,
# And the rose whirled
# And the rose fell like a bell.
# That a rose it grew,
#
# And a rose it was,
# And a rose it grew.
# In her prime it grew,
# And the rose in her sweets
# Was bright and sweet and fair
# Quatrain estimation: 2
# Poem:
# " Singled Individual Aspects," and sign the Sign of Winde,
# Or early to me sung beside the winding of the stream
# Which thee may know, and know thee know,
# For a dream might not have been fancied
# Amongst the snow-and-white of thy thought.
# Or a dream might not have been conceived
#
# Amongst the white of thy fancy.
# One moment of one thought's repose
# The other moment of one thought's repose
#
# Hath given birth to one thought.
# Sweet thought of what a child is withal
# And what a child is withal
# With dreams of His love, and dreams of His love,
#
# And dreams of Him not to be.
# The thought is an anodyne
# And one can love who has learned
# The reason for love's deepest joy.
# And one can love, if one be
#
# One face of the mother's face.
# The thought of a
# Quatrain estimation: 1
# Poem:
# Then her cheek with its scrupulosity
# O'erlooks the deepest charms that lie
#
# In her nobler and brighter likeness.
# And her eyes sparkle with heavenly,
# And she seems to know within
# The secrets of him household with her
#
# Who does her best to be
# Discreet, and thus she sits down among
# The cares to which
#
# The lovers are addicted.
# In her early days
# Would she have suffered all
#
# That the world and the world
# Could have made to feel
# Of her love or bay
#
# And her heart's eternity.
# Not she, but she woke
#
# As men wake from sleep,
# And she would have been
#
# For the longest season
# Of the same world's life.
# But she was
#
# Non-existent-
# The real man
# Of the rest.
# HER CAREER.—
# Osprey, in his Voy
# Quatrain estimation: 1
# Poem:
# And night, that, once the witch of old dream'd to know,
# Comes to her wake with passion to disunite.
# Thro' her insane and hopeless bliss,
#
# Thro' her op'ning vision's dream,
# And over the regious hearth,
# The sighing pastures hear,
#
# The farthest pastures hear,
# And round the ghostly bier
#
# He holds her hovering,
# And on her bier he bears,
# And her eyes do not look
# Onward, wild bright eyes.
# She looks with happy eyes,
#
# And her face to him from thence
# Makes the silent sigh
# Of her soul to him,
# And from him he speaks.
# He holds her spirited in eyes," and therewith
#
# She gazes thereon.
# And he with him gazed,
# And thus they gazed,
# For they gazed with them.
# He gaz
# Quatrain estimation: 0
# Poem:
# A lovely stillous atmosphere
# Of beauty and softness, ethereal, to me
# Sweet eyes, like ether, and touchless brow,
# And life's most intangible
#
# power about
# And haze of calm,
# The eye, the ear,
# The touch, the breath,
# That haunt the face,
#
# the brow,
# The heart and the soul,
# With one mysterious
#
# chain of beauty,
# Forethought and memory.
# And I seem to fasten,
# With one sweet,
#
# one void,
# Like everfold,
# My all of time—
# His all, his thoughts and looks.
# And tell confidences
#
# Me, and fear not
# To meet with me
# In this world of earth
#
# And alien ends
# And sourly,
# And silently,
# And so,
#
# Just enough
# And sufficiently
# The brief life
# Of my life,
# And hours, and days
# Quatrain estimation: 3
# Poem:
# The grass before the shed.
# The footsteps of her father's night,
#
# Her face, lay resting,
# Thought she was alone, alone
#
# And strange to take her place
# For she had been forever
# The child of the deserted place,
# The naked, broken piece
#
# And that was her place,
# The feet of the father.
# With all their sense of health
# And all their hope and will,
#
# The breath of the thought
# Which it might avert,
# The sinews away from her.
# Enough! Enough!
#
# The whole world was made,
#
# And she vying with her,
# That could be made
# But was not made.
# O'er every heart,
#
# That could be made
# To give glad greeting
# To what might be made,
# The same heart had
# Looked from the left
#
# And called me
# My father,
# And called me
#
#
# Quatrain estimation: 4
# Poem:
# And with the mirror of their harmonies to bring
# The Past from its oaths; its vices to forgive,
# And the Remitter to him in all his sorrows.
# The wings of scepticism have first adjusted
#
# To the scale of thought, and marred the progress
# Of ages by conflicting influences.
# The age of what we would have all to lie
#
# In the shadow of the philosopher's see.
# The age of the philosopher's see
# To the day of fame; the hats of the world
# Was gone, and the poets of the world,
#
# Passing from the broadsides of fame.
# And the nations were left in rottenness,
# And the time was no more.
# There it was,
#
# And the anti-isoLarian
# The ignorant
#
# Hath inquired,
# And the wise
#
# Have eagerly sought
# The scales of knowledge
# And the logic of wisdom.
# And then weighed
# Quatrain estimation: 4
# TrainOutput(global_step=250, training_loss=0.005283422563225031, metrics={'train_runtime': 1074.7294, 'train_samples_per_second': 0.93, 'train_steps_per_second': 0.233, 'total_flos': 0.0, 'train_loss': 0.005283422563225031})

# %%
output_dir = "my_trained_model"
trainer.save_model(output_dir)

# 2. For inference, you can load the model and tokenizer
from transformers import AutoModelForCausalLM

# Load the saved model
model = AutoModelForCausalLM.from_pretrained(output_dir)
model.eval()  # Set to evaluation mode
# Out:
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(65536, 1024)
#     (layers): ModuleList(
#       (0-25): 26 x LlamaDecoderLayer(
#         (self_attn): LlamaAttention(
#           (q_proj): Linear(in_features=1024, out_features=1024, bias=False)
#           (k_proj): Linear(in_features=1024, out_features=512, bias=False)
#           (v_proj): Linear(in_features=1024, out_features=512, bias=False)
#           (o_proj): Linear(in_features=1024, out_features=1024, bias=False)
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear(in_features=1024, out_features=2560, bias=False)
#           (up_proj): Linear(in_features=1024, out_features=2560, bias=False)
#           (down_proj): Linear(in_features=2560, out_features=1024, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): LlamaRMSNorm((1024,), eps=1e-05)
#         (post_attention_layernorm): LlamaRMSNorm((1024,), eps=1e-05)
#       )
#     )
#     (norm): LlamaRMSNorm((1024,), eps=1e-05)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=1024, out_features=65536, bias=False)
# )

# %% [markdown]
# We are now ready to run some inference:

# %%
# 3. Test inference
def generate_text(prompt, model, tokenizer, max_length=200):
    inputs = tokenizer(prompt, return_tensors="pt", padding=True)

    # Move to the same device as model
    inputs = {k: v.to(model.device) for k, v in inputs.items()}

    # Generate
    outputs = model.generate(
        **inputs,
        max_length=max_length,
        num_return_sequences=1,
        repetition_penalty=1,
        temperature=0.7,
        do_sample=True,
        pad_token_id=tokenizer.pad_token_id
    )

    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# %%
from pprint import pprint

test_prompt = """Saturn is fallen, am I too to fall?
Am I to leave this haven of my rest,
"""
generated_text = generate_text(test_prompt, model, wrapped_tokenizer)
print(f"Generated: {generated_text}")
# Out:
# Generated: Saturn is fallen, am I too to fall?
# Am I to leave this haven of my rest,
#
# And to part with all that life has made me,
# That I might know what love was and what
# It is.
# For in the same place from which I flew,
# I saw a young man so happy,
#
# Who did not care for me at first;
# To him he never went.
# He had no love but the love he bore.
# He had the heart of an old man,
#
# And could love nothing else.
# The woman whom he loved
# Was the mother of my children:
# She knew how to be kind,
#
# And yet she could have none.
# His love was only the love
# Of her nature and his own ;
# But her nature was different.
# For she was beautiful.
# Now Saturn is fallen,
#
# And I lie in the tomb.
# With our blood we shall meet again

# %% [markdown]
# A very nice thing with pure RL training: while nearly all of our prompt set is English, this does not harm at all the multilingual capacities of the original model. Instead, the new poetic rules transfer very well to a new language:

# %%
test_prompt = """Vers l’Azur attendri d’Octobre pâle et pur
"""
generated_text = generate_text(test_prompt, model, wrapped_tokenizer)
print(f"Generated: {generated_text}")
# Out:
# Generated: Vers l’Azur attendri d’Octobre pâle et pur
# Le Ciel des vents et du vent est plein,
# Et la terre ne se découvre plus guère.
# Les nuages sont moins grands que ceux de ces jours;
# On ne voit pas encore le matin; mais on croit voir
# Depuis deux heures du matin les étoiles noires.
# Du ciel une lumière qui vient de loin
#
# Doit paraître en couleur, à la vue du monde ;
# Elle monte aussi dans notre âme
# Par ce mystère si doux
# Pour nous faire penser aux choses célestes :
#
# C’est elle dont il faut tenir compte...
# Aussi cette nuit va-t-elle bientôt sonner
# Dans nos yeux pour entendre les sons que produit
# L'ombre du jour ou les rayons du soir.
# Mais dès que nous aurons vu
# Ce qui s’envole avec la lumière,
#
# La connaissance aura besoin
# De quelques
